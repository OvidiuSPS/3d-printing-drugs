# %%
import pandas as pd

# %%
# Specify the path to your Excel file
file_path = 'Etapa3_DATE MODELATE_RF 11.2024.xlsx'

# Read all sheets into a dictionary of DataFrames
all_sheets = pd.read_excel(file_path, sheet_name=None)


# Iterate through the dictionary of DataFrames
for sheet_name, df in all_sheets.items():
    # Add a new column with the sheet name
    df['SheetName'] = sheet_name
    
    # Assign the DataFrame to a variable named after the sheet name
    globals()[sheet_name] = df
    globals()[sheet_name].set_index('Primary ID', inplace=True)
    globals()[sheet_name].drop(columns=['Sec ID', 'SheetName'], inplace=True)

# %%
X1 = globals()['Input1_Etapa3']
X2 = globals()['Input2_Etapa3']
y = globals()['Output_Etapa3']
X = pd.merge(X1, X2, left_index=True, right_index=True)

# %%
X
# Out:
#             nAcid   ALogP    ALogp2       AMR      apol  naAromAtom  \
# Primary ID
# BCS1_S1         0  0.7160  0.512656  112.2327  60.25982           6
# BCS1_S2         0  0.7160  0.512656  112.2327  60.25982           6
# BCS1_S3         0  0.7160  0.512656  112.2327  60.25982           6
# BCS1_S4         0  0.7160  0.512656  112.2327  60.25982           6
# BCS1_S5         0  0.7160  0.512656  112.2327  60.25982           6
# ...           ...     ...       ...       ...       ...         ...
# PS-S16          1  1.8296  3.347436   83.8478  39.03872          12
# PS-S17          1  1.8296  3.347436   83.8478  39.03872          12
# PS-S18          1  1.8296  3.347436   83.8478  39.03872          12
# PS-S19          1  1.8296  3.347436   83.8478  39.03872          12
# PS-S20          1  1.8296  3.347436   83.8478  39.03872          12
#
#             nAromBond  nAtom  nHeavyAtom  nH  ...  Bioavailability Score  \
# Primary ID                                    ...
# BCS1_S1             6     53          28  25  ...                   0.55
# BCS1_S2             6     53          28  25  ...                   0.55
# BCS1_S3             6     53          28  25  ...                   0.55
# BCS1_S4             6     53          28  25  ...                   0.55
# BCS1_S5             6     53          28  25  ...                   0.55
# ...               ...    ...         ...  ..  ...                    ...
# PS-S16             12     30          19  11  ...                   0.85
# PS-S17             12     30          19  11  ...                   0.85
# PS-S18             12     30          19  11  ...                   0.85
# PS-S19             12     30          19  11  ...                   0.85
# PS-S20             12     30          19  11  ...                   0.85
#
#             PAINS #alerts  Brenk #alerts  Leadlikeness #violations  \
# Primary ID
# BCS1_S1                 0              1                         2
# BCS1_S2                 0              1                         2
# BCS1_S3                 0              1                         2
# BCS1_S4                 0              1                         2
# BCS1_S5                 0              1                         2
# ...                   ...            ...                       ...
# PS-S16                  0              0                         1
# PS-S17                  0              0                         1
# PS-S18                  0              0                         1
# PS-S19                  0              0                         1
# PS-S20                  0              0                         1
#
#             Synthetic Accessibility  API %  Plast %  ST-Diam (mm)  \
# Primary ID
# BCS1_S1                        4.39      5      0.0          1.99
# BCS1_S2                        4.39      5      0.0          1.91
# BCS1_S3                        4.39      5      0.0          1.91
# BCS1_S4                        4.39      5      0.0          1.91
# BCS1_S5                        4.39      5      0.0          1.90
# ...                             ...    ...      ...           ...
# PS-S16                         2.23     25     15.0          1.78
# PS-S17                         2.23     25     15.0          1.86
# PS-S18                         2.23     25     15.0          1.92
# PS-S19                         2.23     25     15.0          1.84
# PS-S20                         2.23     25     15.0          1.90
#
#             3PBT-Diam (mm)  3PBT-Radius (mm)
# Primary ID
# BCS1_S1               1.88             0.940
# BCS1_S2               1.77             0.885
# BCS1_S3               1.82             0.910
# BCS1_S4               1.91             0.955
# BCS1_S5               1.83             0.915
# ...                    ...               ...
# PS-S16                1.86             0.930
# PS-S17                1.86             0.930
# PS-S18                1.83             0.915
# PS-S19                1.89             0.945
# PS-S20                1.77             0.885
#
# [680 rows x 1509 columns]

# %%
X.shape
# Out:
# (680, 1509)

# %%
y
# Out:
#             ST-Hardness (g)  ST-Rigidity at 2% deformation (g)  \
# Primary ID
# BCS1_S1              8075.0                             1260.0
# BCS1_S2             10205.0                             2630.0
# BCS1_S3              1700.0                              350.0
# BCS1_S4              8145.0                             1745.0
# BCS1_S5              9005.0                             2480.0
# ...                     ...                                ...
# PS-S16               1215.0                              350.0
# PS-S17               1200.0                              300.0
# PS-S18               1480.0                              425.0
# PS-S19               1150.0                              265.0
# PS-S20               1650.0                              420.0
#
#             ST-Rigidity at 4% deformation (g)  ST-Peak stress (N/mp)  \
# Primary ID
# BCS1_S1                                5550.0             25462604.0
# BCS1_S2                                7460.0             34869988.0
# BCS1_S3                                 875.0              5808817.0
# BCS1_S4                                5935.0             27831068.0
# BCS1_S5                                6770.0             31094676.0
# ...                                       ...                    ...
# PS-S16                                  915.0              4785170.0
# PS-S17                                  750.0              4326460.0
# PS-S18                                 1010.0              5004770.0
# PS-S19                                  750.0              4239720.0
# PS-S20                                 1120.0              5697530.0
#
#             3PBT-Hardness (g)  3PBT-Deformation at hardness (mm)  \
# Primary ID
# BCS1_S1                1532.0                               5.79
# BCS1_S2                1083.0                               5.88
# BCS1_S3                1111.5                               6.48
# BCS1_S4                1618.0                               5.81
# BCS1_S5                   NaN                                NaN
# ...                       ...                                ...
# PS-S16                  187.5                               1.05
# PS-S17                  242.0                               1.15
# PS-S18                  206.5                               1.14
# PS-S19                  249.0                               1.14
# PS-S20                  209.0                               2.86
#
#             3PBT-Total work (mJ)  3PBT-Maximum force (N)  \
# Primary ID
# BCS1_S1                    15.65                 15.0136
# BCS1_S2                     9.75                 10.6134
# BCS1_S3                    12.08                 10.8927
# BCS1_S4                    17.65                 15.8564
# BCS1_S5                      NaN                     NaN
# ...                          ...                     ...
# PS-S16                      1.21                  1.8375
# PS-S17                      1.61                  2.3716
# PS-S18                      1.30                  2.0237
# PS-S19                      1.63                  2.4402
# PS-S20                      1.68                  2.0482
#
#             3PBT-Peak stress (N/mp)  \
# Primary ID
# BCS1_S1                   5404240.0
# BCS1_S2                   4317318.0
# BCS1_S3                   4192343.0
# BCS1_S4                   5528627.0
# BCS1_S5                         NaN
# ...                             ...
# PS-S16                     676010.0
# PS-S17                     872503.0
# PS-S18                     769990.0
# PS-S19                     868988.0
# PS-S20                     833167.0
#
#             3PBT-Flexural stress (g/mmp) (Samaro 2021 Prasad 2019)  \
# Primary ID
# BCS1_S1                                            143.916849
# BCS1_S2                                            121.908807
# BCS1_S3                                            115.085796
# BCS1_S4                                            144.945534
# BCS1_S5                                                   NaN
# ...                                                       ...
# PS-S16                                              18.188200
# PS-S17                                              23.474900
# PS-S18                                              21.032600
# PS-S19                                              23.021900
# PS-S20                                              23.526300
#
#             3PBT-Flexural strain (%)  3PBT-Breaking distance (mm)  \
# Primary ID
# BCS1_S1                    10.449792                         5.79
# BCS1_S2                     9.991296                         5.88
# BCS1_S3                    11.321856                         6.48
# BCS1_S4                    10.653216                         5.81
# BCS1_S5                          NaN                          NaN
# ...                              ...                          ...
# PS-S16                      1.874880                         1.05
# PS-S17                      2.053440                         1.15
# PS-S18                      2.002750                         1.14
# PS-S19                      2.068420                         1.14
# PS-S20                      4.859710                         2.86
#
#             3PBT-Stiffness (N/mm) (Hu 2022)
# Primary ID
# BCS1_S1                            2.593022
# BCS1_S2                            1.805000
# BCS1_S3                            1.680972
# BCS1_S4                            2.729157
# BCS1_S5                                 NaN
# ...                                     ...
# PS-S16                             1.750000
# PS-S17                             2.062260
# PS-S18                             1.775180
# PS-S19                             2.140530
# PS-S20                             0.716154
#
# [680 rows x 13 columns]

# %%
# List of columns to drop
columns_to_drop = ['Sec ID', 'SheetName']

# Drop the columns only if they exist in the DataFrame
X = X.drop(columns=[col for col in columns_to_drop if col in X.columns], errors='ignore')
y = y.drop(columns=[col for col in columns_to_drop if col in y.columns], errors='ignore')

# Check the first few rows after dropping the columns
print(X.head())
print(y.head())

# check nr de linii
assert X.shape[0] == y.shape[0]
# Out:
#             nAcid  ALogP    ALogp2       AMR      apol  naAromAtom  nAromBond  \
# Primary ID
# BCS1_S1         0  0.716  0.512656  112.2327  60.25982           6          6
# BCS1_S2         0  0.716  0.512656  112.2327  60.25982           6          6
# BCS1_S3         0  0.716  0.512656  112.2327  60.25982           6          6
# BCS1_S4         0  0.716  0.512656  112.2327  60.25982           6          6
# BCS1_S5         0  0.716  0.512656  112.2327  60.25982           6          6
#
#             nAtom  nHeavyAtom  nH  ...  Bioavailability Score  PAINS #alerts  \
# Primary ID                         ...
# BCS1_S1        53          28  25  ...                   0.55              0
# BCS1_S2        53          28  25  ...                   0.55              0
# BCS1_S3        53          28  25  ...                   0.55              0
# BCS1_S4        53          28  25  ...                   0.55              0
# BCS1_S5        53          28  25  ...                   0.55              0
#
#             Brenk #alerts  Leadlikeness #violations  Synthetic Accessibility  \
# Primary ID
# BCS1_S1                 1                         2                     4.39
# BCS1_S2                 1                         2                     4.39
# BCS1_S3                 1                         2                     4.39
# BCS1_S4                 1                         2                     4.39
# BCS1_S5                 1                         2                     4.39
#
#             API %  Plast %  ST-Diam (mm)  3PBT-Diam (mm)  3PBT-Radius (mm)
# Primary ID
# BCS1_S1         5      0.0          1.99            1.88             0.940
# BCS1_S2         5      0.0          1.91            1.77             0.885
# BCS1_S3         5      0.0          1.91            1.82             0.910
# BCS1_S4         5      0.0          1.91            1.91             0.955
# BCS1_S5         5      0.0          1.90            1.83             0.915
#
# [5 rows x 1509 columns]
#             ST-Hardness (g)  ST-Rigidity at 2% deformation (g)  \
# Primary ID
# BCS1_S1              8075.0                             1260.0
# BCS1_S2             10205.0                             2630.0
# BCS1_S3              1700.0                              350.0
# BCS1_S4              8145.0                             1745.0
# BCS1_S5              9005.0                             2480.0
#
#             ST-Rigidity at 4% deformation (g)  ST-Peak stress (N/mp)  \
# Primary ID
# BCS1_S1                                5550.0             25462604.0
# BCS1_S2                                7460.0             34869988.0
# BCS1_S3                                 875.0              5808817.0
# BCS1_S4                                5935.0             27831068.0
# BCS1_S5                                6770.0             31094676.0
#
#             3PBT-Hardness (g)  3PBT-Deformation at hardness (mm)  \
# Primary ID
# BCS1_S1                1532.0                               5.79
# BCS1_S2                1083.0                               5.88
# BCS1_S3                1111.5                               6.48
# BCS1_S4                1618.0                               5.81
# BCS1_S5                   NaN                                NaN
#
#             3PBT-Total work (mJ)  3PBT-Maximum force (N)  \
# Primary ID
# BCS1_S1                    15.65                 15.0136
# BCS1_S2                     9.75                 10.6134
# BCS1_S3                    12.08                 10.8927
# BCS1_S4                    17.65                 15.8564
# BCS1_S5                      NaN                     NaN
#
#             3PBT-Peak stress (N/mp)  \
# Primary ID
# BCS1_S1                   5404240.0
# BCS1_S2                   4317318.0
# BCS1_S3                   4192343.0
# BCS1_S4                   5528627.0
# BCS1_S5                         NaN
#
#             3PBT-Flexural stress (g/mmp) (Samaro 2021 Prasad 2019)  \
# Primary ID
# BCS1_S1                                            143.916849
# BCS1_S2                                            121.908807
# BCS1_S3                                            115.085796
# BCS1_S4                                            144.945534
# BCS1_S5                                                   NaN
#
#             3PBT-Flexural strain (%)  3PBT-Breaking distance (mm)  \
# Primary ID
# BCS1_S1                    10.449792                         5.79
# BCS1_S2                     9.991296                         5.88
# BCS1_S3                    11.321856                         6.48
# BCS1_S4                    10.653216                         5.81
# BCS1_S5                          NaN                          NaN
#
#             3PBT-Stiffness (N/mm) (Hu 2022)
# Primary ID
# BCS1_S1                            2.593022
# BCS1_S2                            1.805000
# BCS1_S3                            1.680972
# BCS1_S4                            2.729157
# BCS1_S5                                 NaN

# %%
X.columns
# Out:
# Index(['nAcid', 'ALogP', 'ALogp2', 'AMR', 'apol', 'naAromAtom', 'nAromBond',
#        'nAtom', 'nHeavyAtom', 'nH',
#        ...
#        'Bioavailability Score', 'PAINS #alerts', 'Brenk #alerts',
#        'Leadlikeness #violations', 'Synthetic Accessibility', 'API %',
#        'Plast %', 'ST-Diam (mm)', '3PBT-Diam (mm)', '3PBT-Radius (mm)'],
#       dtype='object', length=1509)

# %%
# Identify rows with NaNs
data = pd.merge(X, y, left_index=True, right_index=True)

rows_with_nans = data.isnull().any(axis=1)
num_rows_with_nans = rows_with_nans.sum()
total_rows = len(data)
fraction_rows_with_nans = num_rows_with_nans / total_rows

print(f"Number of rows with NaNs: {num_rows_with_nans}")
print(f"Fraction of rows with NaNs: {fraction_rows_with_nans:.2f}")

# Identify columns with NaNs
columns_with_nans = data.columns[data.isnull().any()].tolist()
num_columns_with_nans = len(columns_with_nans)

print(f"Columns with NaNs: {columns_with_nans}")

# Print detailed information about NaNs in each column
nan_info = data.isnull().sum()
print("\nDetailed NaN information:")
print(nan_info[nan_info > 0])
# Out:
# Number of rows with NaNs: 102
# Fraction of rows with NaNs: 0.15
# Columns with NaNs: ['MW_Spartan', 'Energy', 'Solvation E', 'HOMO', 'Dipol', 'Tautomeri', 'LUMO', 'Conformeri', 'Area A^2', 'Volum A^3', 'Acc area A^2', 'Min ElPot kJ/mol', 'MinLocIonPot kJ/mol', 'LogP', 'PSA A^2', 'Ovality', 'MaxElPot kJ/mo', 'Polaririzability', 'ZPE kJ/mol', 'H0', 'Cv', 'S0', 'G0', 'ST-Diam (mm)', '3PBT-Diam (mm)', '3PBT-Radius (mm)', 'ST-Hardness (g)', 'ST-Rigidity at 2% deformation (g)', 'ST-Rigidity at 4% deformation (g)', 'ST-Peak stress (N/mp)', '3PBT-Hardness (g)', '3PBT-Deformation at hardness (mm)', '3PBT-Total work (mJ)', '3PBT-Maximum force (N)', '3PBT-Peak stress (N/mp)', '3PBT-Flexural stress (g/mmp) (Samaro 2021 Prasad 2019)', '3PBT-Flexural strain (%)', '3PBT-Breaking distance (mm)', '3PBT-Stiffness (N/mm) (Hu 2022)']
#
# Detailed NaN information:
# MW_Spartan                                                55
# Energy                                                    55
# Solvation E                                               55
# HOMO                                                      55
# Dipol                                                     55
# Tautomeri                                                 55
# LUMO                                                      55
# Conformeri                                                55
# Area A^2                                                  55
# Volum A^3                                                 55
# Acc area A^2                                              55
# Min ElPot kJ/mol                                          55
# MinLocIonPot kJ/mol                                       55
# LogP                                                      55
# PSA A^2                                                   55
# Ovality                                                   55
# MaxElPot kJ/mo                                            55
# Polaririzability                                          55
# ZPE kJ/mol                                                55
# H0                                                        55
# Cv                                                        55
# S0                                                        55
# G0                                                        55
# ST-Diam (mm)                                              30
# 3PBT-Diam (mm)                                            37
# 3PBT-Radius (mm)                                           3
# ST-Hardness (g)                                           30
# ST-Rigidity at 2% deformation (g)                         30
# ST-Rigidity at 4% deformation (g)                         30
# ST-Peak stress (N/mp)                                     30
# 3PBT-Hardness (g)                                         38
# 3PBT-Deformation at hardness (mm)                         38
# 3PBT-Total work (mJ)                                      42
# 3PBT-Maximum force (N)                                    38
# 3PBT-Peak stress (N/mp)                                   38
# 3PBT-Flexural stress (g/mmp) (Samaro 2021 Prasad 2019)    53
# 3PBT-Flexural strain (%)                                  38
# 3PBT-Breaking distance (mm)                               38
# 3PBT-Stiffness (N/mm) (Hu 2022)                           38
# dtype: int64

# %%
# Get the indices of rows containing NaN values in df_X
nan_indices = data[data.isna().any(axis=1)].index
print(f"Rows with NaNs: {nan_indices}")
# Out:
# Rows with NaNs: Index(['BCS1_S5', 'BCS2_S80', 'BCS2_S116', 'BCS2_S117', 'BCS2_S118',
#        'BCS2_S119', 'BCS2_S120', 'BCS3_S31', 'BCS3_S32', 'BCS3_S33',
#        ...
#        'BCS4_S102', 'BCS4_S103', 'BCS4_S104', 'BCS4_S105', 'BCS4_S106',
#        'BCS4_S107', 'BCS4_S108', 'BCS4_S109', 'BCS4_S110', 'BCS4_S160'],
#       dtype='object', name='Primary ID', length=102)

# %%
data[columns_with_nans].to_csv('nans.csv')

# %%
# Remove rows with these indices in both df_X and df_y
data.drop(nan_indices, inplace=True)

# %%
X_final = data[X.columns]
y_final = data[y.columns]

# %%
X_final
# Out:
#             nAcid   ALogP    ALogp2       AMR      apol  naAromAtom  \
# Primary ID
# BCS1_S1         0  0.7160  0.512656  112.2327  60.25982           6
# BCS1_S2         0  0.7160  0.512656  112.2327  60.25982           6
# BCS1_S3         0  0.7160  0.512656  112.2327  60.25982           6
# BCS1_S4         0  0.7160  0.512656  112.2327  60.25982           6
# BCS1_S6         0  0.7160  0.512656  112.2327  60.25982           6
# ...           ...     ...       ...       ...       ...         ...
# PS-S16          1  1.8296  3.347436   83.8478  39.03872          12
# PS-S17          1  1.8296  3.347436   83.8478  39.03872          12
# PS-S18          1  1.8296  3.347436   83.8478  39.03872          12
# PS-S19          1  1.8296  3.347436   83.8478  39.03872          12
# PS-S20          1  1.8296  3.347436   83.8478  39.03872          12
#
#             nAromBond  nAtom  nHeavyAtom  nH  ...  Bioavailability Score  \
# Primary ID                                    ...
# BCS1_S1             6     53          28  25  ...                   0.55
# BCS1_S2             6     53          28  25  ...                   0.55
# BCS1_S3             6     53          28  25  ...                   0.55
# BCS1_S4             6     53          28  25  ...                   0.55
# BCS1_S6             6     53          28  25  ...                   0.55
# ...               ...    ...         ...  ..  ...                    ...
# PS-S16             12     30          19  11  ...                   0.85
# PS-S17             12     30          19  11  ...                   0.85
# PS-S18             12     30          19  11  ...                   0.85
# PS-S19             12     30          19  11  ...                   0.85
# PS-S20             12     30          19  11  ...                   0.85
#
#             PAINS #alerts  Brenk #alerts  Leadlikeness #violations  \
# Primary ID
# BCS1_S1                 0              1                         2
# BCS1_S2                 0              1                         2
# BCS1_S3                 0              1                         2
# BCS1_S4                 0              1                         2
# BCS1_S6                 0              1                         2
# ...                   ...            ...                       ...
# PS-S16                  0              0                         1
# PS-S17                  0              0                         1
# PS-S18                  0              0                         1
# PS-S19                  0              0                         1
# PS-S20                  0              0                         1
#
#             Synthetic Accessibility  API %  Plast %  ST-Diam (mm)  \
# Primary ID
# BCS1_S1                        4.39      5      0.0          1.99
# BCS1_S2                        4.39      5      0.0          1.91
# BCS1_S3                        4.39      5      0.0          1.91
# BCS1_S4                        4.39      5      0.0          1.91
# BCS1_S6                        4.39     15      0.0          1.81
# ...                             ...    ...      ...           ...
# PS-S16                         2.23     25     15.0          1.78
# PS-S17                         2.23     25     15.0          1.86
# PS-S18                         2.23     25     15.0          1.92
# PS-S19                         2.23     25     15.0          1.84
# PS-S20                         2.23     25     15.0          1.90
#
#             3PBT-Diam (mm)  3PBT-Radius (mm)
# Primary ID
# BCS1_S1               1.88             0.940
# BCS1_S2               1.77             0.885
# BCS1_S3               1.82             0.910
# BCS1_S4               1.91             0.955
# BCS1_S6               1.61             0.805
# ...                    ...               ...
# PS-S16                1.86             0.930
# PS-S17                1.86             0.930
# PS-S18                1.83             0.915
# PS-S19                1.89             0.945
# PS-S20                1.77             0.885
#
# [578 rows x 1509 columns]

# %%
y_final
# Out:
#             ST-Hardness (g)  ST-Rigidity at 2% deformation (g)  \
# Primary ID
# BCS1_S1              8075.0                             1260.0
# BCS1_S2             10205.0                             2630.0
# BCS1_S3              1700.0                              350.0
# BCS1_S4              8145.0                             1745.0
# BCS1_S6              3570.0                              415.0
# ...                     ...                                ...
# PS-S16               1215.0                              350.0
# PS-S17               1200.0                              300.0
# PS-S18               1480.0                              425.0
# PS-S19               1150.0                              265.0
# PS-S20               1650.0                              420.0
#
#             ST-Rigidity at 4% deformation (g)  ST-Peak stress (N/mp)  \
# Primary ID
# BCS1_S1                                5550.0             25462604.0
# BCS1_S2                                7460.0             34869988.0
# BCS1_S3                                 875.0              5808817.0
# BCS1_S4                                5935.0             27831068.0
# BCS1_S6                                2190.0             13622467.0
# ...                                       ...                    ...
# PS-S16                                  915.0              4785170.0
# PS-S17                                  750.0              4326460.0
# PS-S18                                 1010.0              5004770.0
# PS-S19                                  750.0              4239720.0
# PS-S20                                 1120.0              5697530.0
#
#             3PBT-Hardness (g)  3PBT-Deformation at hardness (mm)  \
# Primary ID
# BCS1_S1                1532.0                               5.79
# BCS1_S2                1083.0                               5.88
# BCS1_S3                1111.5                               6.48
# BCS1_S4                1618.0                               5.81
# BCS1_S6                 750.5                               6.05
# ...                       ...                                ...
# PS-S16                  187.5                               1.05
# PS-S17                  242.0                               1.15
# PS-S18                  206.5                               1.14
# PS-S19                  249.0                               1.14
# PS-S20                  209.0                               2.86
#
#             3PBT-Total work (mJ)  3PBT-Maximum force (N)  \
# Primary ID
# BCS1_S1                    15.65                 15.0136
# BCS1_S2                     9.75                 10.6134
# BCS1_S3                    12.08                 10.8927
# BCS1_S4                    17.65                 15.8564
# BCS1_S6                     6.98                  7.3549
# ...                          ...                     ...
# PS-S16                      1.21                  1.8375
# PS-S17                      1.61                  2.3716
# PS-S18                      1.30                  2.0237
# PS-S19                      1.63                  2.4402
# PS-S20                      1.68                  2.0482
#
#             3PBT-Peak stress (N/mp)  \
# Primary ID
# BCS1_S1                   5404240.0
# BCS1_S2                   4317318.0
# BCS1_S3                   4192343.0
# BCS1_S4                   5528627.0
# BCS1_S6                   3607790.0
# ...                             ...
# PS-S16                     676010.0
# PS-S17                     872503.0
# PS-S18                     769990.0
# PS-S19                     868988.0
# PS-S20                     833167.0
#
#             3PBT-Flexural stress (g/mmp) (Samaro 2021 Prasad 2019)  \
# Primary ID
# BCS1_S1                                            143.916849
# BCS1_S2                                            121.908807
# BCS1_S3                                            115.085796
# BCS1_S4                                            144.945534
# BCS1_S6                                            112.253397
# ...                                                       ...
# PS-S16                                              18.188200
# PS-S17                                              23.474900
# PS-S18                                              21.032600
# PS-S19                                              23.021900
# PS-S20                                              23.526300
#
#             3PBT-Flexural strain (%)  3PBT-Breaking distance (mm)  \
# Primary ID
# BCS1_S1                    10.449792                         5.79
# BCS1_S2                     9.991296                         5.88
# BCS1_S3                    11.321856                         6.48
# BCS1_S4                    10.653216                         5.81
# BCS1_S6                     9.350880                         6.05
# ...                              ...                          ...
# PS-S16                      1.874880                         1.05
# PS-S17                      2.053440                         1.15
# PS-S18                      2.002750                         1.14
# PS-S19                      2.068420                         1.14
# PS-S20                      4.859710                         2.86
#
#             3PBT-Stiffness (N/mm) (Hu 2022)
# Primary ID
# BCS1_S1                            2.593022
# BCS1_S2                            1.805000
# BCS1_S3                            1.680972
# BCS1_S4                            2.729157
# BCS1_S6                            1.215686
# ...                                     ...
# PS-S16                             1.750000
# PS-S17                             2.062260
# PS-S18                             1.775180
# PS-S19                             2.140530
# PS-S20                             0.716154
#
# [578 rows x 13 columns]

# %%
non_numeric_columns = X_final.select_dtypes(exclude=['number']).columns
non_numeric_columns
# Out:
# Index([], dtype='object')

# %%
X_final.to_csv('X.csv')
y_final.to_csv('y.csv')
