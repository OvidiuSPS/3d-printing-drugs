# %%
import pandas as pd

# %%
# Specify the path to your Excel file
file_path = 'Etapa4 11.2024.xlsx'

# Read all sheets into a dictionary of DataFrames
all_sheets = pd.read_excel(file_path, sheet_name=None)


# Iterate through the dictionary of DataFrames
for sheet_name, df in all_sheets.items():
    # Add a new column with the sheet name
    df['SheetName'] = sheet_name
    
    # Assign the DataFrame to a variable named after the sheet name
    globals()[sheet_name] = df
    globals()[sheet_name].set_index('Primary ID', inplace=True)

    columns_to_drop = ['Sec ID', 'SheetName']
    # Drop the columns only if they exist in the DataFrame
    globals()[sheet_name] = globals()[sheet_name].drop(columns=[col for col in columns_to_drop if col in globals()[sheet_name].columns], errors='ignore')

# %%
X = globals()['Input1_Etapa4']
y = globals()['Output_Etapa4']

# %%
X
# Out:
#                       API %  Plast %  nAcid   ALogP    ALogp2       AMR  \
# Primary ID
# Amlodipine_N1_1           5      0.0      0  0.7160  0.512656  112.2327
# Amlodipine_N2_1          15      0.0      0  0.7160  0.512656  112.2327
# Amlodipine_N3_1          25      0.0      0  0.7160  0.512656  112.2327
# Amlodipine_N4_1           5      7.5      0  0.7160  0.512656  112.2327
# Amlodipine_N5_1          15      7.5      0  0.7160  0.512656  112.2327
# ...                     ...      ...    ...     ...       ...       ...
# Spironolactona_N10_1     15      7.5      0  1.4012  1.963361  112.2170
# Spironolactona_N11_1     15      7.5      0  1.4012  1.963361  112.2170
# Cafeina_N2_1             15      0.0      0 -0.9595  0.920640   49.7123
# Cafeina_N5_1             15      7.5      0 -0.9595  0.920640   49.7123
# Cafeina_N9_1             25     15.0      0 -0.9595  0.920640   49.7123
#
#                           apol  naAromAtom  nAromBond  nAtom  ...  \
# Primary ID                                                    ...
# Amlodipine_N1_1       60.25982           6          6     53  ...
# Amlodipine_N2_1       60.25982           6          6     53  ...
# Amlodipine_N3_1       60.25982           6          6     53  ...
# Amlodipine_N4_1       60.25982           6          6     53  ...
# Amlodipine_N5_1       60.25982           6          6     53  ...
# ...                        ...         ...        ...    ...  ...
# Spironolactona_N10_1  69.68538           0          0     61  ...
# Spironolactona_N11_1  69.68538           0          0     61  ...
# Cafeina_N2_1          26.75193           5          5     24  ...
# Cafeina_N5_1          26.75193           5          5     24  ...
# Cafeina_N9_1          26.75193           5          5     24  ...
#
#                       Lipinski #violations  Ghose #violations  \
# Primary ID
# Amlodipine_N1_1                          0                  0
# Amlodipine_N2_1                          0                  0
# Amlodipine_N3_1                          0                  0
# Amlodipine_N4_1                          0                  0
# Amlodipine_N5_1                          0                  0
# ...                                    ...                ...
# Spironolactona_N10_1                     0                  0
# Spironolactona_N11_1                     0                  0
# Cafeina_N2_1                             0                  1
# Cafeina_N5_1                             0                  1
# Cafeina_N9_1                             0                  1
#
#                       Veber #violations  Egan #violations  Muegge #violations  \
# Primary ID
# Amlodipine_N1_1                       0                 0                   0
# Amlodipine_N2_1                       0                 0                   0
# Amlodipine_N3_1                       0                 0                   0
# Amlodipine_N4_1                       0                 0                   0
# Amlodipine_N5_1                       0                 0                   0
# ...                                 ...               ...                 ...
# Spironolactona_N10_1                  0                 0                   0
# Spironolactona_N11_1                  0                 0                   0
# Cafeina_N2_1                          0                 0                   1
# Cafeina_N5_1                          0                 0                   1
# Cafeina_N9_1                          0                 0                   1
#
#                       Bioavailability Score  PAINS #alerts  Brenk #alerts  \
# Primary ID
# Amlodipine_N1_1                        0.55              0              1
# Amlodipine_N2_1                        0.55              0              1
# Amlodipine_N3_1                        0.55              0              1
# Amlodipine_N4_1                        0.55              0              1
# Amlodipine_N5_1                        0.55              0              1
# ...                                     ...            ...            ...
# Spironolactona_N10_1                   0.55              0              1
# Spironolactona_N11_1                   0.55              0              1
# Cafeina_N2_1                           0.55              0              0
# Cafeina_N5_1                           0.55              0              0
# Cafeina_N9_1                           0.55              0              0
#
#                       Leadlikeness #violations  Synthetic Accessibility
# Primary ID
# Amlodipine_N1_1                              2                     4.39
# Amlodipine_N2_1                              2                     4.39
# Amlodipine_N3_1                              2                     4.39
# Amlodipine_N4_1                              2                     4.39
# Amlodipine_N5_1                              2                     4.39
# ...                                        ...                      ...
# Spironolactona_N10_1                         1                     5.94
# Spironolactona_N11_1                         1                     5.94
# Cafeina_N2_1                                 1                     2.03
# Cafeina_N5_1                                 1                     2.03
# Cafeina_N9_1                                 1                     2.03
#
# [135 rows x 1506 columns]

# %%
X.shape
# Out:
# (135, 1506)

# %%
y
# Out:
#                       Scor imprimabilitate
# Primary ID
# Amlodipine_N1_1                        5.0
# Amlodipine_N2_1                        2.0
# Amlodipine_N3_1                        2.0
# Amlodipine_N4_1                        5.0
# Amlodipine_N5_1                        4.0
# ...                                    ...
# Spironolactona_N10_1                   5.0
# Spironolactona_N11_1                   5.0
# Cafeina_N2_1                           2.0
# Cafeina_N5_1                           2.0
# Cafeina_N9_1                           2.0
#
# [135 rows x 1 columns]

# %%
# List of columns to drop
columns_to_drop = ['Sec ID', 'SheetName']

# Drop the columns only if they exist in the DataFrame
X = X.drop(columns=[col for col in columns_to_drop if col in X.columns], errors='ignore')
y = y.drop(columns=[col for col in columns_to_drop if col in y.columns], errors='ignore')

# Check the first few rows after dropping the columns
print(X.head())
print(y.head())

# check nr de linii
assert X.shape[0] == y.shape[0]
# Out:
#                  API %  Plast %  nAcid  ALogP    ALogp2       AMR      apol  \
# Primary ID
# Amlodipine_N1_1      5      0.0      0  0.716  0.512656  112.2327  60.25982
# Amlodipine_N2_1     15      0.0      0  0.716  0.512656  112.2327  60.25982
# Amlodipine_N3_1     25      0.0      0  0.716  0.512656  112.2327  60.25982
# Amlodipine_N4_1      5      7.5      0  0.716  0.512656  112.2327  60.25982
# Amlodipine_N5_1     15      7.5      0  0.716  0.512656  112.2327  60.25982
#
#                  naAromAtom  nAromBond  nAtom  ...  Lipinski #violations  \
# Primary ID                                     ...
# Amlodipine_N1_1           6          6     53  ...                     0
# Amlodipine_N2_1           6          6     53  ...                     0
# Amlodipine_N3_1           6          6     53  ...                     0
# Amlodipine_N4_1           6          6     53  ...                     0
# Amlodipine_N5_1           6          6     53  ...                     0
#
#                  Ghose #violations  Veber #violations  Egan #violations  \
# Primary ID
# Amlodipine_N1_1                  0                  0                 0
# Amlodipine_N2_1                  0                  0                 0
# Amlodipine_N3_1                  0                  0                 0
# Amlodipine_N4_1                  0                  0                 0
# Amlodipine_N5_1                  0                  0                 0
#
#                  Muegge #violations  Bioavailability Score  PAINS #alerts  \
# Primary ID
# Amlodipine_N1_1                   0                   0.55              0
# Amlodipine_N2_1                   0                   0.55              0
# Amlodipine_N3_1                   0                   0.55              0
# Amlodipine_N4_1                   0                   0.55              0
# Amlodipine_N5_1                   0                   0.55              0
#
#                  Brenk #alerts  Leadlikeness #violations  \
# Primary ID
# Amlodipine_N1_1              1                         2
# Amlodipine_N2_1              1                         2
# Amlodipine_N3_1              1                         2
# Amlodipine_N4_1              1                         2
# Amlodipine_N5_1              1                         2
#
#                  Synthetic Accessibility
# Primary ID
# Amlodipine_N1_1                     4.39
# Amlodipine_N2_1                     4.39
# Amlodipine_N3_1                     4.39
# Amlodipine_N4_1                     4.39
# Amlodipine_N5_1                     4.39
#
# [5 rows x 1506 columns]
#                  Scor imprimabilitate
# Primary ID
# Amlodipine_N1_1                   5.0
# Amlodipine_N2_1                   2.0
# Amlodipine_N3_1                   2.0
# Amlodipine_N4_1                   5.0
# Amlodipine_N5_1                   4.0

# %%
X.columns
# Out:
# Index(['API %', 'Plast %', 'nAcid', 'ALogP', 'ALogp2', 'AMR', 'apol',
#        'naAromAtom', 'nAromBond', 'nAtom',
#        ...
#        'Lipinski #violations', 'Ghose #violations', 'Veber #violations',
#        'Egan #violations', 'Muegge #violations', 'Bioavailability Score',
#        'PAINS #alerts', 'Brenk #alerts', 'Leadlikeness #violations',
#        'Synthetic Accessibility'],
#       dtype='object', length=1506)

# %%
# Identify rows with NaNs
data = pd.merge(X, y, left_index=True, right_index=True)

rows_with_nans = data.isnull().any(axis=1)
num_rows_with_nans = rows_with_nans.sum()
total_rows = len(data)
fraction_rows_with_nans = num_rows_with_nans / total_rows

print(f"Number of rows with NaNs: {num_rows_with_nans}")
print(f"Fraction of rows with NaNs: {fraction_rows_with_nans:.2f}")

# Identify columns with NaNs
columns_with_nans = data.columns[data.isnull().any()].tolist()
num_columns_with_nans = len(columns_with_nans)

print(f"Columns with NaNs: {columns_with_nans}")

# Print detailed information about NaNs in each column
nan_info = data.isnull().sum()
print("\nDetailed NaN information:")
print(nan_info[nan_info > 0])
# Out:
# Number of rows with NaNs: 13
# Fraction of rows with NaNs: 0.10
# Columns with NaNs: ['MW_Spartan', 'Energy', 'Solvation E', 'HOMO', 'Dipol', 'Tautomeri', 'LUMO', 'Conformeri', 'Area A^2', 'Volum A^3', 'Acc area A^2', 'Min ElPot kJ/mol', 'MinLocIonPot kJ/mol', 'LogP', 'PSA A^2', 'Ovality', 'MaxElPot kJ/mo', 'Polaririzability', 'ZPE kJ/mol', 'H0', 'Cv', 'S0', 'G0', 'Scor imprimabilitate']
#
# Detailed NaN information:
# MW_Spartan              11
# Energy                  11
# Solvation E             11
# HOMO                    11
# Dipol                   11
# Tautomeri               11
# LUMO                    11
# Conformeri              11
# Area A^2                11
# Volum A^3               11
# Acc area A^2            11
# Min ElPot kJ/mol        11
# MinLocIonPot kJ/mol     11
# LogP                    11
# PSA A^2                 11
# Ovality                 11
# MaxElPot kJ/mo          11
# Polaririzability        11
# ZPE kJ/mol              11
# H0                      11
# Cv                      11
# S0                      11
# G0                      11
# Scor imprimabilitate     3
# dtype: int64

# %%
# Get the indices of rows containing NaN values in df_X
nan_indices = data[data.isna().any(axis=1)].index
print(f"Rows with NaNs: {nan_indices}")
# Out:
# Rows with NaNs: Index(['Aciclovir_N10_1', 'Hidroclorotiazida_N10_1', 'Azitromicina_N1_1',
#        'Azitromicina_N2_1', 'Azitromicina_N3_1', 'Azitromicina_N4_1',
#        'Azitromicina_N5_1', 'Azitromicina_N6_1', 'Azitromicina_N7_1',
#        'Azitromicina_N8_1', 'Azitromicina_N9_1', 'Azitromicina_N10_1',
#        'Azitromicina_N11_1'],
#       dtype='object', name='Primary ID')

# %%
data[columns_with_nans].to_csv('nans.csv')

# %%
# Remove rows with these indices in both df_X and df_y
data.drop(nan_indices, inplace=True)

# %%
X_final = data[X.columns]
y_final = data[y.columns]

# %%
X_final
# Out:
#                       API %  Plast %  nAcid   ALogP    ALogp2       AMR  \
# Primary ID
# Amlodipine_N1_1           5      0.0      0  0.7160  0.512656  112.2327
# Amlodipine_N2_1          15      0.0      0  0.7160  0.512656  112.2327
# Amlodipine_N3_1          25      0.0      0  0.7160  0.512656  112.2327
# Amlodipine_N4_1           5      7.5      0  0.7160  0.512656  112.2327
# Amlodipine_N5_1          15      7.5      0  0.7160  0.512656  112.2327
# ...                     ...      ...    ...     ...       ...       ...
# Spironolactona_N10_1     15      7.5      0  1.4012  1.963361  112.2170
# Spironolactona_N11_1     15      7.5      0  1.4012  1.963361  112.2170
# Cafeina_N2_1             15      0.0      0 -0.9595  0.920640   49.7123
# Cafeina_N5_1             15      7.5      0 -0.9595  0.920640   49.7123
# Cafeina_N9_1             25     15.0      0 -0.9595  0.920640   49.7123
#
#                           apol  naAromAtom  nAromBond  nAtom  ...  \
# Primary ID                                                    ...
# Amlodipine_N1_1       60.25982           6          6     53  ...
# Amlodipine_N2_1       60.25982           6          6     53  ...
# Amlodipine_N3_1       60.25982           6          6     53  ...
# Amlodipine_N4_1       60.25982           6          6     53  ...
# Amlodipine_N5_1       60.25982           6          6     53  ...
# ...                        ...         ...        ...    ...  ...
# Spironolactona_N10_1  69.68538           0          0     61  ...
# Spironolactona_N11_1  69.68538           0          0     61  ...
# Cafeina_N2_1          26.75193           5          5     24  ...
# Cafeina_N5_1          26.75193           5          5     24  ...
# Cafeina_N9_1          26.75193           5          5     24  ...
#
#                       Lipinski #violations  Ghose #violations  \
# Primary ID
# Amlodipine_N1_1                          0                  0
# Amlodipine_N2_1                          0                  0
# Amlodipine_N3_1                          0                  0
# Amlodipine_N4_1                          0                  0
# Amlodipine_N5_1                          0                  0
# ...                                    ...                ...
# Spironolactona_N10_1                     0                  0
# Spironolactona_N11_1                     0                  0
# Cafeina_N2_1                             0                  1
# Cafeina_N5_1                             0                  1
# Cafeina_N9_1                             0                  1
#
#                       Veber #violations  Egan #violations  Muegge #violations  \
# Primary ID
# Amlodipine_N1_1                       0                 0                   0
# Amlodipine_N2_1                       0                 0                   0
# Amlodipine_N3_1                       0                 0                   0
# Amlodipine_N4_1                       0                 0                   0
# Amlodipine_N5_1                       0                 0                   0
# ...                                 ...               ...                 ...
# Spironolactona_N10_1                  0                 0                   0
# Spironolactona_N11_1                  0                 0                   0
# Cafeina_N2_1                          0                 0                   1
# Cafeina_N5_1                          0                 0                   1
# Cafeina_N9_1                          0                 0                   1
#
#                       Bioavailability Score  PAINS #alerts  Brenk #alerts  \
# Primary ID
# Amlodipine_N1_1                        0.55              0              1
# Amlodipine_N2_1                        0.55              0              1
# Amlodipine_N3_1                        0.55              0              1
# Amlodipine_N4_1                        0.55              0              1
# Amlodipine_N5_1                        0.55              0              1
# ...                                     ...            ...            ...
# Spironolactona_N10_1                   0.55              0              1
# Spironolactona_N11_1                   0.55              0              1
# Cafeina_N2_1                           0.55              0              0
# Cafeina_N5_1                           0.55              0              0
# Cafeina_N9_1                           0.55              0              0
#
#                       Leadlikeness #violations  Synthetic Accessibility
# Primary ID
# Amlodipine_N1_1                              2                     4.39
# Amlodipine_N2_1                              2                     4.39
# Amlodipine_N3_1                              2                     4.39
# Amlodipine_N4_1                              2                     4.39
# Amlodipine_N5_1                              2                     4.39
# ...                                        ...                      ...
# Spironolactona_N10_1                         1                     5.94
# Spironolactona_N11_1                         1                     5.94
# Cafeina_N2_1                                 1                     2.03
# Cafeina_N5_1                                 1                     2.03
# Cafeina_N9_1                                 1                     2.03
#
# [122 rows x 1506 columns]

# %%
y_final
# Out:
#                       Scor imprimabilitate
# Primary ID
# Amlodipine_N1_1                        5.0
# Amlodipine_N2_1                        2.0
# Amlodipine_N3_1                        2.0
# Amlodipine_N4_1                        5.0
# Amlodipine_N5_1                        4.0
# ...                                    ...
# Spironolactona_N10_1                   5.0
# Spironolactona_N11_1                   5.0
# Cafeina_N2_1                           2.0
# Cafeina_N5_1                           2.0
# Cafeina_N9_1                           2.0
#
# [122 rows x 1 columns]

# %%
non_numeric_columns = X_final.select_dtypes(exclude=['number']).columns
non_numeric_columns
# Out:
# Index([], dtype='object')

# %%
X_final.to_csv('X.csv')
y_final.to_csv('y.csv')
