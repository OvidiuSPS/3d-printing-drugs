# %%
import pandas as pd

# %%
# Specify the path to your Excel file
file_path = 'Etapa6 - completat 11.2024.xlsx'

# Read all sheets into a dictionary of DataFrames
all_sheets = pd.read_excel(file_path, sheet_name=None)


# Iterate through the dictionary of DataFrames
for sheet_name, df in all_sheets.items():
    # Add a new column with the sheet name
    df['SheetName'] = sheet_name
    
    # Assign the DataFrame to a variable named after the sheet name
    globals()[sheet_name] = df
    globals()[sheet_name].set_index('Primary ID', inplace=True)

    columns_to_drop = ['Sec ID', 'SheetName']
    # Drop the columns only if they exist in the DataFrame
    globals()[sheet_name] = globals()[sheet_name].drop(columns=[col for col in columns_to_drop if col in globals()[sheet_name].columns], errors='ignore')

# %%
X1 = globals()['Input1_Etapa6']
X2 = globals()['Input2_Etapa6']
y = globals()['Output_Etapa6']
X = pd.merge(X1, X2, left_index=True, right_index=True)

# %%
X
# Out:
#             nAcid   ALogP    ALogp2       AMR      apol  naAromAtom  \
# Primary ID
# BCS1_S1         0  0.7160  0.512656  112.2327  60.25982           6
# BCS1_S2         0  0.7160  0.512656  112.2327  60.25982           6
# BCS1_S3         0  0.7160  0.512656  112.2327  60.25982           6
# BCS1_S4         0  0.7160  0.512656  112.2327  60.25982           6
# BCS1_S5         0  0.7160  0.512656  112.2327  60.25982           6
# ...           ...     ...       ...       ...       ...         ...
# BCS4_S161       0  1.4012  1.963361  112.2170  69.68538           0
# BCS4_S162       0  1.4012  1.963361  112.2170  69.68538           0
# BCS4_S163       0  1.4012  1.963361  112.2170  69.68538           0
# BCS4_S164       0  1.4012  1.963361  112.2170  69.68538           0
# BCS4_S165       0  1.4012  1.963361  112.2170  69.68538           0
#
#             nAromBond  nAtom  nHeavyAtom  nH  ...  Scor imprimabilitate  \
# Primary ID                                    ...
# BCS1_S1             6     53          28  25  ...                   5.0
# BCS1_S2             6     53          28  25  ...                   5.0
# BCS1_S3             6     53          28  25  ...                   5.0
# BCS1_S4             6     53          28  25  ...                   5.0
# BCS1_S5             6     53          28  25  ...                   5.0
# ...               ...    ...         ...  ..  ...                   ...
# BCS4_S161           0     61          29  32  ...                   5.0
# BCS4_S162           0     61          29  32  ...                   5.0
# BCS4_S163           0     61          29  32  ...                   5.0
# BCS4_S164           0     61          29  32  ...                   5.0
# BCS4_S165           0     61          29  32  ...                   5.0
#
#             API dose      %5min     %10min     %15min     %30min     %60min  \
# Primary ID
# BCS1_S1          8.6  10.032837  13.726531  17.440437  20.014301  33.023403
# BCS1_S2          8.6  10.032837  13.726531  17.440437  20.014301  33.023403
# BCS1_S3          8.6  10.032837  13.726531  17.440437  20.014301  33.023403
# BCS1_S4          8.6  10.032837  13.726531  17.440437  20.014301  33.023403
# BCS1_S5          8.6  10.032837  13.726531  17.440437  20.014301  33.023403
# ...              ...        ...        ...        ...        ...        ...
# BCS4_S161        NaN        NaN        NaN        NaN        NaN        NaN
# BCS4_S162        NaN        NaN        NaN        NaN        NaN        NaN
# BCS4_S163        NaN        NaN        NaN        NaN        NaN        NaN
# BCS4_S164        NaN        NaN        NaN        NaN        NaN        NaN
# BCS4_S165        NaN        NaN        NaN        NaN        NaN        NaN
#
#               %120min    %180min    %240min
# Primary ID
# BCS1_S1     56.301913  57.734695  59.174676
# BCS1_S2     56.301913  57.734695  59.174676
# BCS1_S3     56.301913  57.734695  59.174676
# BCS1_S4     56.301913  57.734695  59.174676
# BCS1_S5     56.301913  57.734695  59.174676
# ...               ...        ...        ...
# BCS4_S161         NaN        NaN        NaN
# BCS4_S162         NaN        NaN        NaN
# BCS4_S163         NaN        NaN        NaN
# BCS4_S164         NaN        NaN        NaN
# BCS4_S165         NaN        NaN        NaN
#
# [660 rows x 1530 columns]

# %%
X.shape
# Out:
# (660, 1530)

# %%
y
# Out:
#             Temperatura  duză de imprimare (grade)  \
# Primary ID
# BCS1_S1                                      190.0
# BCS1_S2                                      190.0
# BCS1_S3                                      190.0
# BCS1_S4                                      190.0
# BCS1_S5                                      190.0
# ...                                            ...
# BCS4_S161                                      NaN
# BCS4_S162                                      NaN
# BCS4_S163                                      NaN
# BCS4_S164                                      NaN
# BCS4_S165                                      NaN
#
#             Temperatura pat imprimare (grade)  Viteză de imprimare (x = ori)
# Primary ID
# BCS1_S1                                  60.0                            1.0
# BCS1_S2                                  60.0                            1.0
# BCS1_S3                                  60.0                            1.0
# BCS1_S4                                  60.0                            1.0
# BCS1_S5                                  60.0                            1.0
# ...                                       ...                            ...
# BCS4_S161                                 NaN                            NaN
# BCS4_S162                                 NaN                            NaN
# BCS4_S163                                 NaN                            NaN
# BCS4_S164                                 NaN                            NaN
# BCS4_S165                                 NaN                            NaN
#
# [660 rows x 3 columns]

# %%
# List of columns to drop
columns_to_drop = ['Sec ID', 'SheetName']

# Drop the columns only if they exist in the DataFrame
X = X.drop(columns=[col for col in columns_to_drop if col in X.columns], errors='ignore')
y = y.drop(columns=[col for col in columns_to_drop if col in y.columns], errors='ignore')

# Check the first few rows after dropping the columns
print(X.head())
print(y.head())

# check nr de linii
assert X.shape[0] == y.shape[0]
# Out:
#             nAcid  ALogP    ALogp2       AMR      apol  naAromAtom  nAromBond  \
# Primary ID
# BCS1_S1         0  0.716  0.512656  112.2327  60.25982           6          6
# BCS1_S2         0  0.716  0.512656  112.2327  60.25982           6          6
# BCS1_S3         0  0.716  0.512656  112.2327  60.25982           6          6
# BCS1_S4         0  0.716  0.512656  112.2327  60.25982           6          6
# BCS1_S5         0  0.716  0.512656  112.2327  60.25982           6          6
#
#             nAtom  nHeavyAtom  nH  ...  Scor imprimabilitate  API dose  \
# Primary ID                         ...
# BCS1_S1        53          28  25  ...                   5.0       8.6
# BCS1_S2        53          28  25  ...                   5.0       8.6
# BCS1_S3        53          28  25  ...                   5.0       8.6
# BCS1_S4        53          28  25  ...                   5.0       8.6
# BCS1_S5        53          28  25  ...                   5.0       8.6
#
#                 %5min     %10min     %15min     %30min     %60min    %120min  \
# Primary ID
# BCS1_S1     10.032837  13.726531  17.440437  20.014301  33.023403  56.301913
# BCS1_S2     10.032837  13.726531  17.440437  20.014301  33.023403  56.301913
# BCS1_S3     10.032837  13.726531  17.440437  20.014301  33.023403  56.301913
# BCS1_S4     10.032837  13.726531  17.440437  20.014301  33.023403  56.301913
# BCS1_S5     10.032837  13.726531  17.440437  20.014301  33.023403  56.301913
#
#               %180min    %240min
# Primary ID
# BCS1_S1     57.734695  59.174676
# BCS1_S2     57.734695  59.174676
# BCS1_S3     57.734695  59.174676
# BCS1_S4     57.734695  59.174676
# BCS1_S5     57.734695  59.174676
#
# [5 rows x 1530 columns]
#             Temperatura  duză de imprimare (grade)  \
# Primary ID
# BCS1_S1                                      190.0
# BCS1_S2                                      190.0
# BCS1_S3                                      190.0
# BCS1_S4                                      190.0
# BCS1_S5                                      190.0
#
#             Temperatura pat imprimare (grade)  Viteză de imprimare (x = ori)
# Primary ID
# BCS1_S1                                  60.0                            1.0
# BCS1_S2                                  60.0                            1.0
# BCS1_S3                                  60.0                            1.0
# BCS1_S4                                  60.0                            1.0
# BCS1_S5                                  60.0                            1.0

# %%
X.columns
# Out:
# Index(['nAcid', 'ALogP', 'ALogp2', 'AMR', 'apol', 'naAromAtom', 'nAromBond',
#        'nAtom', 'nHeavyAtom', 'nH',
#        ...
#        'Scor imprimabilitate', 'API dose', '%5min', '%10min', '%15min',
#        '%30min', '%60min', '%120min', '%180min', '%240min'],
#       dtype='object', length=1530)

# %%
# Identify rows with NaNs
data = pd.merge(X, y, left_index=True, right_index=True)

rows_with_nans = data.isnull().any(axis=1)
num_rows_with_nans = rows_with_nans.sum()
total_rows = len(data)
fraction_rows_with_nans = num_rows_with_nans / total_rows

print(f"Number of rows with NaNs: {num_rows_with_nans}")
print(f"Fraction of rows with NaNs: {fraction_rows_with_nans:.2f}")

# Identify columns with NaNs
columns_with_nans = data.columns[data.isnull().any()].tolist()
num_columns_with_nans = len(columns_with_nans)

print(f"Columns with NaNs: {columns_with_nans}")

# Print detailed information about NaNs in each column
nan_info = data.isnull().sum()
print("\nDetailed NaN information:")
print(nan_info[nan_info > 0])
# Out:
# Number of rows with NaNs: 201
# Fraction of rows with NaNs: 0.30
# Columns with NaNs: ['MW_Spartan', 'Energy', 'Solvation E', 'HOMO', 'Dipol', 'Tautomeri', 'LUMO', 'Conformeri', 'Area A^2', 'Volum A^3', 'Acc area A^2', 'Min ElPot kJ/mol', 'MinLocIonPot kJ/mol', 'LogP', 'PSA A^2', 'Ovality', 'MaxElPot kJ/mo', 'Polaririzability', 'ZPE kJ/mol', 'H0', 'Cv', 'S0', 'G0', 'ST-Hardness (g)', 'ST-Rigidity at 2% deformation (g)', 'ST-Rigidity at 4% deformation (g)', 'ST-Peak stress (N/mp)', '3PBT-Hardness (g)', '3PBT-Deformation at hardness (mm)', '3PBT-Total work (mJ)', '3PBT-Maximum force (N)', '3PBT-Peak stress (N/mp)', '3PBT-Flexural stress (g/mmp) (Samaro 2021 Prasad 2019)', '3PBT-Flexural strain (%)', '3PBT-Breaking distance (mm)', '3PBT-Stiffness (N/mm) (Hu 2022)', 'Scor imprimabilitate', 'API dose', '%5min', '%10min', '%15min', '%30min', '%60min', '%120min', '%180min', '%240min', 'Temperatura  duză de imprimare (grade)', 'Temperatura pat imprimare (grade)', 'Viteză de imprimare (x = ori)']
#
# Detailed NaN information:
# MW_Spartan                                                 55
# Energy                                                     55
# Solvation E                                                55
# HOMO                                                       55
# Dipol                                                      55
# Tautomeri                                                  55
# LUMO                                                       55
# Conformeri                                                 55
# Area A^2                                                   55
# Volum A^3                                                  55
# Acc area A^2                                               55
# Min ElPot kJ/mol                                           55
# MinLocIonPot kJ/mol                                        55
# LogP                                                       55
# PSA A^2                                                    55
# Ovality                                                    55
# MaxElPot kJ/mo                                             55
# Polaririzability                                           55
# ZPE kJ/mol                                                 55
# H0                                                         55
# Cv                                                         55
# S0                                                         55
# G0                                                         55
# ST-Hardness (g)                                            30
# ST-Rigidity at 2% deformation (g)                          30
# ST-Rigidity at 4% deformation (g)                          30
# ST-Peak stress (N/mp)                                      30
# 3PBT-Hardness (g)                                          38
# 3PBT-Deformation at hardness (mm)                          38
# 3PBT-Total work (mJ)                                       42
# 3PBT-Maximum force (N)                                     38
# 3PBT-Peak stress (N/mp)                                    38
# 3PBT-Flexural stress (g/mmp) (Samaro 2021 Prasad 2019)     53
# 3PBT-Flexural strain (%)                                   38
# 3PBT-Breaking distance (mm)                                38
# 3PBT-Stiffness (N/mm) (Hu 2022)                            38
# Scor imprimabilitate                                       15
# API dose                                                  100
# %5min                                                     100
# %10min                                                    100
# %15min                                                    100
# %30min                                                    100
# %60min                                                    100
# %120min                                                   100
# %180min                                                   100
# %240min                                                   105
# Temperatura  duză de imprimare (grade)                    100
# Temperatura pat imprimare (grade)                         100
# Viteză de imprimare (x = ori)                             100
# dtype: int64

# %%
# Get the indices of rows containing NaN values in df_X
nan_indices = data[data.isna().any(axis=1)].index
print(f"Rows with NaNs: {nan_indices}")

# Remove rows with these indices in both df_X and df_Y
X.drop(nan_indices, inplace=True)
y.drop(nan_indices, inplace=True)
# Out:
# Rows with NaNs: Index(['BCS1_S5', 'BCS1_S11', 'BCS1_S12', 'BCS1_S13', 'BCS1_S14', 'BCS1_S15',
#        'BCS1_S26', 'BCS1_S27', 'BCS1_S28', 'BCS1_S29',
#        ...
#        'BCS4_S156', 'BCS4_S157', 'BCS4_S158', 'BCS4_S159', 'BCS4_S160',
#        'BCS4_S161', 'BCS4_S162', 'BCS4_S163', 'BCS4_S164', 'BCS4_S165'],
#       dtype='object', name='Primary ID', length=201)

# %%
X
# Out:
#             nAcid   ALogP    ALogp2       AMR      apol  naAromAtom  \
# Primary ID
# BCS1_S1         0  0.7160  0.512656  112.2327  60.25982           6
# BCS1_S2         0  0.7160  0.512656  112.2327  60.25982           6
# BCS1_S3         0  0.7160  0.512656  112.2327  60.25982           6
# BCS1_S4         0  0.7160  0.512656  112.2327  60.25982           6
# BCS1_S6         0  0.7160  0.512656  112.2327  60.25982           6
# ...           ...     ...       ...       ...       ...         ...
# BCS4_S51        0  0.1354  0.018333   44.2004  23.64676           5
# BCS4_S52        0  0.1354  0.018333   44.2004  23.64676           5
# BCS4_S53        0  0.1354  0.018333   44.2004  23.64676           5
# BCS4_S54        0  0.1354  0.018333   44.2004  23.64676           5
# BCS4_S55        0  0.1354  0.018333   44.2004  23.64676           5
#
#             nAromBond  nAtom  nHeavyAtom  nH  ...  Scor imprimabilitate  \
# Primary ID                                    ...
# BCS1_S1             6     53          28  25  ...                   5.0
# BCS1_S2             6     53          28  25  ...                   5.0
# BCS1_S3             6     53          28  25  ...                   5.0
# BCS1_S4             6     53          28  25  ...                   5.0
# BCS1_S6             6     53          28  25  ...                   2.0
# ...               ...    ...         ...  ..  ...                   ...
# BCS4_S51            5     19          13   6  ...                   5.0
# BCS4_S52            5     19          13   6  ...                   5.0
# BCS4_S53            5     19          13   6  ...                   5.0
# BCS4_S54            5     19          13   6  ...                   5.0
# BCS4_S55            5     19          13   6  ...                   5.0
#
#             API dose      %5min     %10min     %15min     %30min     %60min  \
# Primary ID
# BCS1_S1        8.600  10.032837  13.726531  17.440437  20.014301  33.023403
# BCS1_S2        8.600  10.032837  13.726531  17.440437  20.014301  33.023403
# BCS1_S3        8.600  10.032837  13.726531  17.440437  20.014301  33.023403
# BCS1_S4        8.600  10.032837  13.726531  17.440437  20.014301  33.023403
# BCS1_S6       22.725   8.265069  11.232801  14.216765  14.427015  26.217518
# ...              ...        ...        ...        ...        ...        ...
# BCS4_S51      23.475   9.034772  13.207822  17.418949  30.098115  60.671289
# BCS4_S52      23.475   9.034772  13.207822  17.418949  30.098115  60.671289
# BCS4_S53      23.475   9.034772  13.207822  17.418949  30.098115  60.671289
# BCS4_S54      23.475   9.034772  13.207822  17.418949  30.098115  60.671289
# BCS4_S55      23.475   9.034772  13.207822  17.418949  30.098115  60.671289
#
#               %120min    %180min    %240min
# Primary ID
# BCS1_S1     56.301913  57.734695  59.174676
# BCS1_S2     56.301913  57.734695  59.174676
# BCS1_S3     56.301913  57.734695  59.174676
# BCS1_S4     56.301913  57.734695  59.174676
# BCS1_S6     45.604998  48.168232  53.780585
# ...               ...        ...        ...
# BCS4_S51    94.554427  95.354641  95.914246
# BCS4_S52    94.554427  95.354641  95.914246
# BCS4_S53    94.554427  95.354641  95.914246
# BCS4_S54    94.554427  95.354641  95.914246
# BCS4_S55    94.554427  95.354641  95.914246
#
# [459 rows x 1530 columns]

# %%
y
# Out:
#             Temperatura  duză de imprimare (grade)  \
# Primary ID
# BCS1_S1                                      190.0
# BCS1_S2                                      190.0
# BCS1_S3                                      190.0
# BCS1_S4                                      190.0
# BCS1_S6                                      190.0
# ...                                            ...
# BCS4_S51                                     160.0
# BCS4_S52                                     160.0
# BCS4_S53                                     160.0
# BCS4_S54                                     160.0
# BCS4_S55                                     160.0
#
#             Temperatura pat imprimare (grade)  Viteză de imprimare (x = ori)
# Primary ID
# BCS1_S1                                  60.0                            1.0
# BCS1_S2                                  60.0                            1.0
# BCS1_S3                                  60.0                            1.0
# BCS1_S4                                  60.0                            1.0
# BCS1_S6                                  60.0                            1.0
# ...                                       ...                            ...
# BCS4_S51                                 60.0                            1.0
# BCS4_S52                                 60.0                            1.0
# BCS4_S53                                 60.0                            1.0
# BCS4_S54                                 60.0                            1.0
# BCS4_S55                                 60.0                            1.0
#
# [459 rows x 3 columns]

# %%
non_numeric_columns = X.select_dtypes(exclude=['number']).columns
X[non_numeric_columns]
# Out:
#            Unnamed: 2
# Primary ID
# BCS1_S1            N1
# BCS1_S2            N1
# BCS1_S3            N1
# BCS1_S4            N1
# BCS1_S6            N2
# ...               ...
# BCS4_S51          N11
# BCS4_S52          N11
# BCS4_S53          N11
# BCS4_S54          N11
# BCS4_S55          N11
#
# [459 rows x 1 columns]

# %%
print(X[non_numeric_columns])
# Out:
#            Unnamed: 2
# Primary ID
# BCS1_S1            N1
# BCS1_S2            N1
# BCS1_S3            N1
# BCS1_S4            N1
# BCS1_S6            N2
# BCS1_S7            N2
# BCS1_S8            N2
# BCS1_S9            N2
# BCS1_S10           N2
# BCS1_S16           N4
# BCS1_S17           N4
# BCS1_S18           N4
# BCS1_S19           N4
# BCS1_S20           N4
# BCS1_S21           N5
# BCS1_S22           N5
# BCS1_S23           N5
# BCS1_S24           N5
# BCS1_S25           N5
# BCS1_S46          N10
# BCS1_S47          N10
# BCS1_S48          N10
# BCS1_S49          N10
# BCS1_S50          N10
# BCS1_S51          N11
# BCS1_S52          N11
# BCS1_S53          N11
# BCS1_S54          N11
# BCS1_S55          N11
# BCS1_S56           N1
# BCS1_S57           N1
# BCS1_S58           N1
# BCS1_S59           N1
# BCS1_S60           N1
# BCS1_S61           N2
# BCS1_S62           N2
# BCS1_S63           N2
# BCS1_S64           N2
# BCS1_S65           N2
# BCS1_S66           N3
# BCS1_S67           N3
# BCS1_S68           N3
# BCS1_S69           N3
# BCS1_S70           N3
# BCS1_S71           N4
# BCS1_S72           N4
# BCS1_S73           N4
# BCS1_S74           N4
# BCS1_S75           N4
# BCS1_S76           N5
# BCS1_S77           N5
# BCS1_S78           N5
# BCS1_S79           N5
# BCS1_S80           N5
# BCS1_S81           N6
# BCS1_S82           N6
# BCS1_S83           N6
# BCS1_S84           N6
# BCS1_S85           N6
# BCS1_S86           N7
# BCS1_S87           N7
# BCS1_S88           N7
# BCS1_S89           N7
# BCS1_S90           N7
# BCS1_S91           N8
# BCS1_S92           N8
# BCS1_S93           N8
# BCS1_S94           N8
# BCS1_S95           N8
# BCS1_S96           N9
# BCS1_S97           N9
# BCS1_S98           N9
# BCS1_S99           N9
# BCS1_S100          N9
# BCS1_S101         N10
# BCS1_S102         N10
# BCS1_S103         N10
# BCS1_S104         N10
# BCS1_S105         N10
# BCS1_S106         N11
# BCS1_S107         N11
# BCS1_S108         N11
# BCS1_S109         N11
# BCS1_S110         N11
# BCS1_S111          N1
# BCS1_S112          N1
# BCS1_S113          N1
# BCS1_S114          N1
# BCS1_S115          N1
# BCS1_S116          N2
# BCS1_S117          N2
# BCS1_S118          N2
# BCS1_S119          N2
# BCS1_S120          N2
# BCS1_S121          N3
# BCS1_S122          N3
# BCS1_S123          N3
# BCS1_S124          N3
# BCS1_S125          N3
# BCS1_S126          N4
# BCS1_S127          N4
# BCS1_S128          N4
# BCS1_S129          N4
# BCS1_S130          N4
# BCS1_S131          N5
# BCS1_S132          N5
# BCS1_S133          N5
# BCS1_S134          N5
# BCS1_S135          N5
# BCS1_S136          N6
# BCS1_S137          N6
# BCS1_S138          N6
# BCS1_S139          N6
# BCS1_S140          N6
# BCS1_S141          N7
# BCS1_S142          N7
# BCS1_S143          N7
# BCS1_S144          N7
# BCS1_S145          N7
# BCS1_S146          N8
# BCS1_S147          N8
# BCS1_S148          N8
# BCS1_S149          N8
# BCS1_S150          N8
# BCS1_S151          N9
# BCS1_S152          N9
# BCS1_S153          N9
# BCS1_S154          N9
# BCS1_S155          N9
# BCS1_S156         N10
# BCS1_S157         N10
# BCS1_S158         N10
# BCS1_S159         N10
# BCS1_S160         N10
# BCS1_S161         N11
# BCS1_S162         N11
# BCS1_S163         N11
# BCS1_S164         N11
# BCS1_S165         N11
# BCS2_S1            N1
# BCS2_S2            N1
# BCS2_S3            N1
# BCS2_S4            N1
# BCS2_S5            N1
# BCS2_S11           N3
# BCS2_S12           N3
# BCS2_S13           N3
# BCS2_S14           N3
# BCS2_S15           N3
# BCS2_S16           N4
# BCS2_S17           N4
# BCS2_S18           N4
# BCS2_S19           N4
# BCS2_S20           N4
# BCS2_S21           N5
# BCS2_S22           N5
# BCS2_S23           N5
# BCS2_S24           N5
# BCS2_S25           N5
# BCS2_S31           N7
# BCS2_S32           N7
# BCS2_S33           N7
# BCS2_S34           N7
# BCS2_S35           N7
# BCS2_S36           N8
# BCS2_S37           N8
# BCS2_S38           N8
# BCS2_S39           N8
# BCS2_S40           N8
# BCS2_S41           N9
# BCS2_S42           N9
# BCS2_S43           N9
# BCS2_S44           N9
# BCS2_S45           N9
# BCS2_S46          N10
# BCS2_S47          N10
# BCS2_S48          N10
# BCS2_S49          N10
# BCS2_S50          N10
# BCS2_S51          N11
# BCS2_S52          N11
# BCS2_S53          N11
# BCS2_S54          N11
# BCS2_S55          N11
# BCS2_S56           N1
# BCS2_S57           N1
# BCS2_S58           N1
# BCS2_S59           N1
# BCS2_S60           N1
# BCS2_S61           N2
# BCS2_S62           N2
# BCS2_S63           N2
# BCS2_S64           N2
# BCS2_S65           N2
# BCS2_S66           N3
# BCS2_S67           N3
# BCS2_S68           N3
# BCS2_S69           N3
# BCS2_S70           N3
# BCS2_S71           N4
# BCS2_S72           N4
# BCS2_S73           N4
# BCS2_S74           N4
# BCS2_S75           N4
# BCS2_S76           N5
# BCS2_S77           N5
# BCS2_S78           N5
# BCS2_S79           N5
# BCS2_S81           N6
# BCS2_S82           N6
# BCS2_S83           N6
# BCS2_S84           N6
# BCS2_S85           N6
# BCS2_S86           N7
# BCS2_S87           N7
# BCS2_S88           N7
# BCS2_S89           N7
# BCS2_S90           N7
# BCS2_S91           N8
# BCS2_S92           N8
# BCS2_S93           N8
# BCS2_S94           N8
# BCS2_S95           N8
# BCS2_S96           N9
# BCS2_S97           N9
# BCS2_S98           N9
# BCS2_S99           N9
# BCS2_S100          N9
# BCS2_S101         N10
# BCS2_S102         N10
# BCS2_S103         N10
# BCS2_S104         N10
# BCS2_S105         N10
# BCS2_S106         N11
# BCS2_S107         N11
# BCS2_S108         N11
# BCS2_S109         N11
# BCS2_S110         N11
# BCS2_S111          N1
# BCS2_S112          N1
# BCS2_S113          N1
# BCS2_S114          N1
# BCS2_S115          N1
# BCS2_S126          N4
# BCS2_S127          N4
# BCS2_S128          N4
# BCS2_S129          N4
# BCS2_S130          N4
# BCS2_S131          N5
# BCS2_S132          N5
# BCS2_S133          N5
# BCS2_S134          N5
# BCS2_S135          N5
# BCS2_S136          N6
# BCS2_S137          N6
# BCS2_S138          N6
# BCS2_S139          N6
# BCS2_S140          N6
# BCS2_S141          N7
# BCS2_S142          N7
# BCS2_S143          N7
# BCS2_S144          N7
# BCS2_S145          N7
# BCS2_S146          N8
# BCS2_S147          N8
# BCS2_S148          N8
# BCS2_S149          N8
# BCS2_S150          N8
# BCS2_S156         N10
# BCS2_S157         N10
# BCS2_S158         N10
# BCS2_S159         N10
# BCS2_S160         N10
# BCS2_S161         N11
# BCS2_S162         N11
# BCS2_S163         N11
# BCS2_S164         N11
# BCS2_S165         N11
# BCS3_S1            N1
# BCS3_S2            N1
# BCS3_S3            N1
# BCS3_S4            N1
# BCS3_S5            N1
# BCS3_S6            N2
# BCS3_S7            N2
# BCS3_S8            N2
# BCS3_S9            N2
# BCS3_S10           N2
# BCS3_S11           N3
# BCS3_S12           N3
# BCS3_S13           N3
# BCS3_S14           N3
# BCS3_S15           N3
# BCS3_S16           N4
# BCS3_S17           N4
# BCS3_S18           N4
# BCS3_S19           N4
# BCS3_S20           N4
# BCS3_S21           N5
# BCS3_S22           N5
# BCS3_S23           N5
# BCS3_S24           N5
# BCS3_S25           N5
# BCS3_S26           N6
# BCS3_S27           N6
# BCS3_S28           N6
# BCS3_S29           N6
# BCS3_S30           N6
# BCS3_S36           N8
# BCS3_S37           N8
# BCS3_S38           N8
# BCS3_S39           N8
# BCS3_S40           N8
# BCS3_S41           N9
# BCS3_S42           N9
# BCS3_S43           N9
# BCS3_S44           N9
# BCS3_S45           N9
# BCS3_S51          N11
# BCS3_S52          N11
# BCS3_S53          N11
# BCS3_S54          N11
# BCS3_S55          N11
# BCS3_S71           N4
# BCS3_S72           N4
# BCS3_S73           N4
# BCS3_S74           N4
# BCS3_S75           N4
# BCS3_S76           N5
# BCS3_S77           N5
# BCS3_S78           N5
# BCS3_S79           N5
# BCS3_S80           N5
# BCS3_S81           N6
# BCS3_S82           N6
# BCS3_S83           N6
# BCS3_S84           N6
# BCS3_S85           N6
# BCS3_S86           N7
# BCS3_S87           N7
# BCS3_S88           N7
# BCS3_S89           N7
# BCS3_S90           N7
# BCS3_S91           N8
# BCS3_S92           N8
# BCS3_S93           N8
# BCS3_S94           N8
# BCS3_S95           N8
# BCS3_S96           N9
# BCS3_S97           N9
# BCS3_S98           N9
# BCS3_S99           N9
# BCS3_S100          N9
# BCS3_S101         N10
# BCS3_S102         N10
# BCS3_S103         N10
# BCS3_S104         N10
# BCS3_S105         N10
# BCS3_S106         N11
# BCS3_S107         N11
# BCS3_S108         N11
# BCS3_S109         N11
# BCS3_S110         N11
# BCS3_S111          N1
# BCS3_S112          N1
# BCS3_S113          N1
# BCS3_S114          N1
# BCS3_S115          N1
# BCS3_S116          N2
# BCS3_S117          N2
# BCS3_S118          N2
# BCS3_S119          N2
# BCS3_S120          N2
# BCS3_S121          N3
# BCS3_S122          N3
# BCS3_S123          N3
# BCS3_S124          N3
# BCS3_S125          N3
# BCS3_S126          N4
# BCS3_S127          N4
# BCS3_S128          N4
# BCS3_S129          N4
# BCS3_S130          N4
# BCS3_S131          N5
# BCS3_S132          N5
# BCS3_S133          N5
# BCS3_S134          N5
# BCS3_S135          N5
# BCS3_S136          N6
# BCS3_S137          N6
# BCS3_S138          N6
# BCS3_S139          N6
# BCS3_S140          N6
# BCS3_S141          N7
# BCS3_S142          N7
# BCS3_S143          N7
# BCS3_S144          N7
# BCS3_S145          N7
# BCS3_S146          N8
# BCS3_S147          N8
# BCS3_S148          N8
# BCS3_S149          N8
# BCS3_S150          N8
# BCS3_S151          N9
# BCS3_S152          N9
# BCS3_S153          N9
# BCS3_S161         N11
# BCS3_S162         N11
# BCS3_S163         N11
# BCS4_S1            N1
# BCS4_S2            N1
# BCS4_S3            N1
# BCS4_S4            N1
# BCS4_S5            N1
# BCS4_S6            N2
# BCS4_S7            N2
# BCS4_S8            N2
# BCS4_S9            N2
# BCS4_S10           N2
# BCS4_S11           N3
# BCS4_S12           N3
# BCS4_S13           N3
# BCS4_S14           N3
# BCS4_S15           N3
# BCS4_S16           N4
# BCS4_S17           N4
# BCS4_S18           N4
# BCS4_S19           N4
# BCS4_S20           N4
# BCS4_S21           N5
# BCS4_S22           N5
# BCS4_S23           N5
# BCS4_S24           N5
# BCS4_S25           N5
# BCS4_S31           N7
# BCS4_S32           N7
# BCS4_S33           N7
# BCS4_S34           N7
# BCS4_S35           N7
# BCS4_S36           N8
# BCS4_S37           N8
# BCS4_S38           N8
# BCS4_S39           N8
# BCS4_S40           N8
# BCS4_S41           N9
# BCS4_S42           N9
# BCS4_S43           N9
# BCS4_S44           N9
# BCS4_S45           N9
# BCS4_S46          N10
# BCS4_S47          N10
# BCS4_S48          N10
# BCS4_S49          N10
# BCS4_S50          N10
# BCS4_S51          N11
# BCS4_S52          N11
# BCS4_S53          N11
# BCS4_S54          N11
# BCS4_S55          N11

# %%
X.to_csv('X.csv')
y.to_csv('y.csv')
