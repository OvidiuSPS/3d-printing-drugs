# %%
import pandas as pd

# %%
# Specify the path to your Excel file
file_path = 'Etapa2 - completat 11.2024.xlsx'

# Read all sheets into a dictionary of DataFrames
all_sheets = pd.read_excel(file_path, sheet_name=None)


# Iterate through the dictionary of DataFrames
for sheet_name, df in all_sheets.items():
    # Add a new column with the sheet name
    df['SheetName'] = sheet_name
    
    # Assign the DataFrame to a variable named after the sheet name
    globals()[sheet_name] = df
    globals()[sheet_name].set_index('Primary ID', inplace=True)

# %%
X = globals()['Input1_Etapa2']
y = globals()['Output_etapa2']

# %%
X
# Out:
#                      Sec ID  API %  Plast %  API dose      %5min     %10min  \
# Primary ID
# Amlodipine_N1_1  Amlodipine      5      0.0      7.90   6.824995  10.599703
# Amlodipine_N1_2  Amlodipine      5      0.0      9.30  13.240678  16.853359
# Amlodipine_N2_1  Amlodipine     15      0.0     23.40   3.087206   5.356809
# Amlodipine_N2_2  Amlodipine     15      0.0     22.05  13.442931  17.108792
# Amlodipine_N4_1  Amlodipine      5      7.5      8.25   4.643496   9.536276
# ...                     ...    ...      ...       ...        ...        ...
# Diclofenac_N2_2  Diclofenac     15      0.0     25.95   5.927844   9.993104
# Diclofenac_N4_1  Diclofenac      5      7.5      7.55   7.781062  10.656150
# Diclofenac_N4_2  Diclofenac      5      7.5      8.10   8.525924  16.088311
# Diclofenac_N5_1  Diclofenac     15      7.5     24.30   7.800232  11.797752
# Diclofenac_N5_2  Diclofenac     15      7.5     23.40   9.089186  14.589624
#
#                     %15min     %30min     %60min    %120min  ...  \
# Primary ID                                                   ...
# Amlodipine_N1_1  14.395172  19.542900  31.676950  49.805138  ...
# Amlodipine_N1_2  20.485702  20.485702  34.369857  62.798687  ...
# Amlodipine_N2_1   7.638926  13.578082  25.862664  45.194778  ...
# Amlodipine_N2_2  20.794604  15.275948  26.572372  46.015217  ...
# Amlodipine_N4_1  14.456096  17.031157  29.929859  45.669082  ...
# ...                    ...        ...        ...        ...  ...
# Diclofenac_N2_2  14.071073  26.080956  47.540045  78.132131  ...
# Diclofenac_N4_1  15.479299  28.957761  51.605898  89.404487  ...
# Diclofenac_N4_2  20.369692  30.854069  58.134071  89.632731  ...
# Diclofenac_N5_1  16.138128  26.122993  51.275688  80.987311  ...
# Diclofenac_N5_2  22.420710  38.055916  78.081678  84.145563  ...
#
#                  Ghose #violations  Veber #violations  Egan #violations  \
# Primary ID
# Amlodipine_N1_1                0.0                0.0               0.0
# Amlodipine_N1_2                0.0                0.0               0.0
# Amlodipine_N2_1                0.0                0.0               0.0
# Amlodipine_N2_2                0.0                0.0               0.0
# Amlodipine_N4_1                0.0                0.0               0.0
# ...                            ...                ...               ...
# Diclofenac_N2_2                0.0                0.0               0.0
# Diclofenac_N4_1                0.0                0.0               0.0
# Diclofenac_N4_2                0.0                0.0               0.0
# Diclofenac_N5_1                0.0                0.0               0.0
# Diclofenac_N5_2                0.0                0.0               0.0
#
#                  Muegge #violations  Bioavailability Score  PAINS #alerts  \
# Primary ID
# Amlodipine_N1_1                 0.0                   0.55            0.0
# Amlodipine_N1_2                 0.0                   0.55            0.0
# Amlodipine_N2_1                 0.0                   0.55            0.0
# Amlodipine_N2_2                 0.0                   0.55            0.0
# Amlodipine_N4_1                 0.0                   0.55            0.0
# ...                             ...                    ...            ...
# Diclofenac_N2_2                 0.0                   0.85            0.0
# Diclofenac_N4_1                 0.0                   0.85            0.0
# Diclofenac_N4_2                 0.0                   0.85            0.0
# Diclofenac_N5_1                 0.0                   0.85            0.0
# Diclofenac_N5_2                 0.0                   0.85            0.0
#
#                  Brenk #alerts  Leadlikeness #violations  \
# Primary ID
# Amlodipine_N1_1            1.0                       2.0
# Amlodipine_N1_2            1.0                       2.0
# Amlodipine_N2_1            1.0                       2.0
# Amlodipine_N2_2            1.0                       2.0
# Amlodipine_N4_1            1.0                       2.0
# ...                        ...                       ...
# Diclofenac_N2_2            0.0                       1.0
# Diclofenac_N4_1            0.0                       1.0
# Diclofenac_N4_2            0.0                       1.0
# Diclofenac_N5_1            0.0                       1.0
# Diclofenac_N5_2            0.0                       1.0
#
#                  Synthetic Accessibility      SheetName
# Primary ID
# Amlodipine_N1_1                     4.39  Input1_Etapa2
# Amlodipine_N1_2                     4.39  Input1_Etapa2
# Amlodipine_N2_1                     4.39  Input1_Etapa2
# Amlodipine_N2_2                     4.39  Input1_Etapa2
# Amlodipine_N4_1                     4.39  Input1_Etapa2
# ...                                  ...            ...
# Diclofenac_N2_2                     2.23  Input1_Etapa2
# Diclofenac_N4_1                     2.23  Input1_Etapa2
# Diclofenac_N4_2                     2.23  Input1_Etapa2
# Diclofenac_N5_1                     2.23  Input1_Etapa2
# Diclofenac_N5_2                     2.23  Input1_Etapa2
#
# [234 rows x 1517 columns]

# %%
X.shape
# Out:
# (234, 1517)

# %%
y
# Out:
#                  Printlet weight      SheetName
# Primary ID
# Amlodipine_N1_1            158.0  Output_etapa2
# Amlodipine_N1_2            186.0  Output_etapa2
# Amlodipine_N2_1            156.0  Output_etapa2
# Amlodipine_N2_2            147.0  Output_etapa2
# Amlodipine_N4_1            165.0  Output_etapa2
# ...                          ...            ...
# Diclofenac_N2_2            173.0  Output_etapa2
# Diclofenac_N4_1            151.0  Output_etapa2
# Diclofenac_N4_2            162.0  Output_etapa2
# Diclofenac_N5_1            162.0  Output_etapa2
# Diclofenac_N5_2            156.0  Output_etapa2
#
# [234 rows x 2 columns]

# %%
# List of columns to drop
columns_to_drop = ['Sec ID', 'SheetName']

# Drop the columns only if they exist in the DataFrame
X = X.drop(columns=[col for col in columns_to_drop if col in X.columns], errors='ignore')
y = y.drop(columns=[col for col in columns_to_drop if col in y.columns], errors='ignore')

# Check the first few rows after dropping the columns
print(X.head())
print(y.head())

# check nr de linii
assert X.shape[0] == y.shape[0]
# Out:
#                  API %  Plast %  API dose      %5min     %10min     %15min  \
# Primary ID
# Amlodipine_N1_1      5      0.0      7.90   6.824995  10.599703  14.395172
# Amlodipine_N1_2      5      0.0      9.30  13.240678  16.853359  20.485702
# Amlodipine_N2_1     15      0.0     23.40   3.087206   5.356809   7.638926
# Amlodipine_N2_2     15      0.0     22.05  13.442931  17.108792  20.794604
# Amlodipine_N4_1      5      7.5      8.25   4.643496   9.536276  14.456096
#
#                     %30min     %60min    %120min    %180min  ...  \
# Primary ID                                                   ...
# Amlodipine_N1_1  19.542900  31.676950  49.805138  52.670704  ...
# Amlodipine_N1_2  20.485702  34.369857  62.798687  62.798687  ...
# Amlodipine_N2_1  13.578082  25.862664  45.194778  50.321247  ...
# Amlodipine_N2_2  15.275948  26.572372  46.015217  46.015217  ...
# Amlodipine_N4_1  17.031157  29.929859  45.669082  52.007638  ...
#
#                  Lipinski #violations  Ghose #violations  Veber #violations  \
# Primary ID
# Amlodipine_N1_1                   0.0                0.0                0.0
# Amlodipine_N1_2                   0.0                0.0                0.0
# Amlodipine_N2_1                   0.0                0.0                0.0
# Amlodipine_N2_2                   0.0                0.0                0.0
# Amlodipine_N4_1                   0.0                0.0                0.0
#
#                  Egan #violations  Muegge #violations  Bioavailability Score  \
# Primary ID
# Amlodipine_N1_1               0.0                 0.0                   0.55
# Amlodipine_N1_2               0.0                 0.0                   0.55
# Amlodipine_N2_1               0.0                 0.0                   0.55
# Amlodipine_N2_2               0.0                 0.0                   0.55
# Amlodipine_N4_1               0.0                 0.0                   0.55
#
#                  PAINS #alerts  Brenk #alerts  Leadlikeness #violations  \
# Primary ID
# Amlodipine_N1_1            0.0            1.0                       2.0
# Amlodipine_N1_2            0.0            1.0                       2.0
# Amlodipine_N2_1            0.0            1.0                       2.0
# Amlodipine_N2_2            0.0            1.0                       2.0
# Amlodipine_N4_1            0.0            1.0                       2.0
#
#                  Synthetic Accessibility
# Primary ID
# Amlodipine_N1_1                     4.39
# Amlodipine_N1_2                     4.39
# Amlodipine_N2_1                     4.39
# Amlodipine_N2_2                     4.39
# Amlodipine_N4_1                     4.39
#
# [5 rows x 1515 columns]
#                  Printlet weight
# Primary ID
# Amlodipine_N1_1            158.0
# Amlodipine_N1_2            186.0
# Amlodipine_N2_1            156.0
# Amlodipine_N2_2            147.0
# Amlodipine_N4_1            165.0

# %%
X.columns
# Out:
# Index(['API %', 'Plast %', 'API dose', '%5min', '%10min', '%15min', '%30min',
#        '%60min', '%120min', '%180min',
#        ...
#        'Lipinski #violations', 'Ghose #violations', 'Veber #violations',
#        'Egan #violations', 'Muegge #violations', 'Bioavailability Score',
#        'PAINS #alerts', 'Brenk #alerts', 'Leadlikeness #violations',
#        'Synthetic Accessibility'],
#       dtype='object', length=1515)

# %%
# Identify rows with NaNs
data = pd.merge(X, y, left_index=True, right_index=True)

rows_with_nans = data.isnull().any(axis=1)
num_rows_with_nans = rows_with_nans.sum()
total_rows = len(data)
fraction_rows_with_nans = num_rows_with_nans / total_rows

print(f"Number of rows with NaNs: {num_rows_with_nans}")
print(f"Fraction of rows with NaNs: {fraction_rows_with_nans:.2f}")

# Identify columns with NaNs
columns_with_nans = data.columns[data.isnull().any()].tolist()
num_columns_with_nans = len(columns_with_nans)

print(f"Columns with NaNs: {columns_with_nans}")

# Print detailed information about NaNs in each column
nan_info = data.isnull().sum()
print("\nDetailed NaN information:")
print(nan_info[nan_info > 0])
# Out:
# Number of rows with NaNs: 16
# Fraction of rows with NaNs: 0.07
# Columns with NaNs: ['nAcid', 'ALogP', 'ALogp2', 'AMR', 'apol', 'naAromAtom', 'nAromBond', 'nAtom', 'nHeavyAtom', 'nH', 'nB', 'nC', 'nN', 'nO', 'nS', 'nP', 'nF', 'nCl', 'nBr', 'nI', 'nX', 'ATS0m', 'ATS1m', 'ATS2m', 'ATS3m', 'ATS4m', 'ATS5m', 'ATS6m', 'ATS7m', 'ATS8m', 'ATS0v', 'ATS1v', 'ATS2v', 'ATS3v', 'ATS4v', 'ATS5v', 'ATS6v', 'ATS7v', 'ATS8v', 'ATS0e', 'ATS1e', 'ATS2e', 'ATS3e', 'ATS4e', 'ATS5e', 'ATS6e', 'ATS7e', 'ATS8e', 'ATS0p', 'ATS1p', 'ATS2p', 'ATS3p', 'ATS4p', 'ATS5p', 'ATS6p', 'ATS7p', 'ATS8p', 'ATS0i', 'ATS1i', 'ATS2i', 'ATS3i', 'ATS4i', 'ATS5i', 'ATS6i', 'ATS7i', 'ATS8i', 'ATS0s', 'ATS1s', 'ATS2s', 'ATS3s', 'ATS4s', 'ATS5s', 'ATS6s', 'ATS7s', 'ATS8s', 'AATS0m', 'AATS1m', 'AATS2m', 'AATS3m', 'AATS4m', 'AATS5m', 'AATS6m', 'AATS7m', 'AATS8m', 'AATS0v', 'AATS1v', 'AATS2v', 'AATS3v', 'AATS4v', 'AATS5v', 'AATS6v', 'AATS7v', 'AATS8v', 'AATS0e', 'AATS1e', 'AATS2e', 'AATS3e', 'AATS4e', 'AATS5e', 'AATS6e', 'AATS7e', 'AATS8e', 'AATS0p', 'AATS1p', 'AATS2p', 'AATS3p', 'AATS4p', 'AATS5p', 'AATS6p', 'AATS7p', 'AATS8p', 'AATS0i', 'AATS1i', 'AATS2i', 'AATS3i', 'AATS4i', 'AATS5i', 'AATS6i', 'AATS7i', 'AATS8i', 'AATS0s', 'AATS1s', 'AATS2s', 'AATS3s', 'AATS4s', 'AATS5s', 'AATS6s', 'AATS7s', 'AATS8s', 'ATSC0c', 'ATSC1c', 'ATSC2c', 'ATSC3c', 'ATSC4c', 'ATSC5c', 'ATSC6c', 'ATSC7c', 'ATSC8c', 'ATSC0m', 'ATSC1m', 'ATSC2m', 'ATSC3m', 'ATSC4m', 'ATSC5m', 'ATSC6m', 'ATSC7m', 'ATSC8m', 'ATSC0v', 'ATSC1v', 'ATSC2v', 'ATSC3v', 'ATSC4v', 'ATSC5v', 'ATSC6v', 'ATSC7v', 'ATSC8v', 'ATSC0e', 'ATSC1e', 'ATSC2e', 'ATSC3e', 'ATSC4e', 'ATSC5e', 'ATSC6e', 'ATSC7e', 'ATSC8e', 'ATSC0p', 'ATSC1p', 'ATSC2p', 'ATSC3p', 'ATSC4p', 'ATSC5p', 'ATSC6p', 'ATSC7p', 'ATSC8p', 'ATSC0i', 'ATSC1i', 'ATSC2i', 'ATSC3i', 'ATSC4i', 'ATSC5i', 'ATSC6i', 'ATSC7i', 'ATSC8i', 'ATSC0s', 'ATSC1s', 'ATSC2s', 'ATSC3s', 'ATSC4s', 'ATSC5s', 'ATSC6s', 'ATSC7s', 'ATSC8s', 'AATSC0c', 'AATSC1c', 'AATSC2c', 'AATSC3c', 'AATSC4c', 'AATSC5c', 'AATSC6c', 'AATSC7c', 'AATSC8c', 'AATSC0m', 'AATSC1m', 'AATSC2m', 'AATSC3m', 'AATSC4m', 'AATSC5m', 'AATSC6m', 'AATSC7m', 'AATSC8m', 'AATSC0v', 'AATSC1v', 'AATSC2v', 'AATSC3v', 'AATSC4v', 'AATSC5v', 'AATSC6v', 'AATSC7v', 'AATSC8v', 'AATSC0e', 'AATSC1e', 'AATSC2e', 'AATSC3e', 'AATSC4e', 'AATSC5e', 'AATSC6e', 'AATSC7e', 'AATSC8e', 'AATSC0p', 'AATSC1p', 'AATSC2p', 'AATSC3p', 'AATSC4p', 'AATSC5p', 'AATSC6p', 'AATSC7p', 'AATSC8p', 'AATSC0i', 'AATSC1i', 'AATSC2i', 'AATSC3i', 'AATSC4i', 'AATSC5i', 'AATSC6i', 'AATSC7i', 'AATSC8i', 'AATSC0s', 'AATSC1s', 'AATSC2s', 'AATSC3s', 'AATSC4s', 'AATSC5s', 'AATSC6s', 'AATSC7s', 'AATSC8s', 'MATS1c', 'MATS2c', 'MATS3c', 'MATS4c', 'MATS5c', 'MATS6c', 'MATS7c', 'MATS8c', 'MATS1m', 'MATS2m', 'MATS3m', 'MATS4m', 'MATS5m', 'MATS6m', 'MATS7m', 'MATS8m', 'MATS1v', 'MATS2v', 'MATS3v', 'MATS4v', 'MATS5v', 'MATS6v', 'MATS7v', 'MATS8v', 'MATS1e', 'MATS2e', 'MATS3e', 'MATS4e', 'MATS5e', 'MATS6e', 'MATS7e', 'MATS8e', 'MATS1p', 'MATS2p', 'MATS3p', 'MATS4p', 'MATS5p', 'MATS6p', 'MATS7p', 'MATS8p', 'MATS1i', 'MATS2i', 'MATS3i', 'MATS4i', 'MATS5i', 'MATS6i', 'MATS7i', 'MATS8i', 'MATS1s', 'MATS2s', 'MATS3s', 'MATS4s', 'MATS5s', 'MATS6s', 'MATS7s', 'MATS8s', 'GATS1c', 'GATS2c', 'GATS3c', 'GATS4c', 'GATS5c', 'GATS6c', 'GATS7c', 'GATS8c', 'GATS1m', 'GATS2m', 'GATS3m', 'GATS4m', 'GATS5m', 'GATS6m', 'GATS7m', 'GATS8m', 'GATS1v', 'GATS2v', 'GATS3v', 'GATS4v', 'GATS5v', 'GATS6v', 'GATS7v', 'GATS8v', 'GATS1e', 'GATS2e', 'GATS3e', 'GATS4e', 'GATS5e', 'GATS6e', 'GATS7e', 'GATS8e', 'GATS1p', 'GATS2p', 'GATS3p', 'GATS4p', 'GATS5p', 'GATS6p', 'GATS7p', 'GATS8p', 'GATS1i', 'GATS2i', 'GATS3i', 'GATS4i', 'GATS5i', 'GATS6i', 'GATS7i', 'GATS8i', 'GATS1s', 'GATS2s', 'GATS3s', 'GATS4s', 'GATS5s', 'GATS6s', 'GATS7s', 'GATS8s', 'SpAbs_DzZ', 'SpMax_DzZ', 'SpDiam_DzZ', 'SpAD_DzZ', 'SpMAD_DzZ', 'EE_DzZ', 'SM1_DzZ', 'VE1_DzZ', 'VE2_DzZ', 'VE3_DzZ', 'VR1_DzZ', 'VR2_DzZ', 'VR3_DzZ', 'SpAbs_Dzm', 'SpMax_Dzm', 'SpDiam_Dzm', 'SpAD_Dzm', 'SpMAD_Dzm', 'EE_Dzm', 'SM1_Dzm', 'VE1_Dzm', 'VE2_Dzm', 'VE3_Dzm', 'VR1_Dzm', 'VR2_Dzm', 'VR3_Dzm', 'SpAbs_Dzv', 'SpMax_Dzv', 'SpDiam_Dzv',  ...
#
# Detailed NaN information:
# nAcid                       2
# ALogP                       2
# ALogp2                      2
# AMR                         2
# apol                        2
#                            ..
# Bioavailability Score       2
# PAINS #alerts               2
# Brenk #alerts               2
# Leadlikeness #violations    2
# Synthetic Accessibility     2
# Length: 1504, dtype: int64

# %%
# Get the indices of rows containing NaN values in df_X
nan_indices = X[X.isna().any(axis=1)].index
print(f"Rows with NaNs: {nan_indices}")

# Remove rows with these indices in both df_X and df_Y
X.drop(nan_indices, inplace=True)
y.drop(nan_indices, inplace=True)
# Out:
# Rows with NaNs: Index(['Acetazolamida_N6_1', 'Acetazolamida_N6_2', 'Azithromycine_N1_1',
#        'Azithromycine_N1_2', 'Azithromycine_N2_1', 'Azithromycine_N2_2',
#        'Azithromycine_N4_1', 'Azithromycine_N4_2', 'Azithromycine_N5_1',
#        'Azithromycine_N5_2', 'Azithromycine_N7_1', 'Azithromycine_N7_2',
#        'Azithromycine_N8_1', 'Azithromycine_N8_2', 'Azithromycine_N9_1',
#        'Azithromycine_N9_2'],
#       dtype='object', name='Primary ID')

# %%
X
# Out:
#                  API %  Plast %  API dose      %5min     %10min     %15min  \
# Primary ID
# Amlodipine_N1_1      5      0.0      7.90   6.824995  10.599703  14.395172
# Amlodipine_N1_2      5      0.0      9.30  13.240678  16.853359  20.485702
# Amlodipine_N2_1     15      0.0     23.40   3.087206   5.356809   7.638926
# Amlodipine_N2_2     15      0.0     22.05  13.442931  17.108792  20.794604
# Amlodipine_N4_1      5      7.5      8.25   4.643496   9.536276  14.456096
# ...                ...      ...       ...        ...        ...        ...
# Diclofenac_N2_2     15      0.0     25.95   5.927844   9.993104  14.071073
# Diclofenac_N4_1      5      7.5      7.55   7.781062  10.656150  15.479299
# Diclofenac_N4_2      5      7.5      8.10   8.525924  16.088311  20.369692
# Diclofenac_N5_1     15      7.5     24.30   7.800232  11.797752  16.138128
# Diclofenac_N5_2     15      7.5     23.40   9.089186  14.589624  22.420710
#
#                     %30min     %60min    %120min    %180min  ...  \
# Primary ID                                                   ...
# Amlodipine_N1_1  19.542900  31.676950  49.805138  52.670704  ...
# Amlodipine_N1_2  20.485702  34.369857  62.798687  62.798687  ...
# Amlodipine_N2_1  13.578082  25.862664  45.194778  50.321247  ...
# Amlodipine_N2_2  15.275948  26.572372  46.015217  46.015217  ...
# Amlodipine_N4_1  17.031157  29.929859  45.669082  52.007638  ...
# ...                    ...        ...        ...        ...  ...
# Diclofenac_N2_2  26.080956  47.540045  78.132131  78.132131  ...
# Diclofenac_N4_1  28.957761  51.605898  89.404487  95.394807  ...
# Diclofenac_N4_2  30.854069  58.134071  89.632731  91.492950  ...
# Diclofenac_N5_1  26.122993  51.275688  80.987311  82.313628  ...
# Diclofenac_N5_2  38.055916  78.081678  84.145563  84.145563  ...
#
#                  Lipinski #violations  Ghose #violations  Veber #violations  \
# Primary ID
# Amlodipine_N1_1                   0.0                0.0                0.0
# Amlodipine_N1_2                   0.0                0.0                0.0
# Amlodipine_N2_1                   0.0                0.0                0.0
# Amlodipine_N2_2                   0.0                0.0                0.0
# Amlodipine_N4_1                   0.0                0.0                0.0
# ...                               ...                ...                ...
# Diclofenac_N2_2                   0.0                0.0                0.0
# Diclofenac_N4_1                   0.0                0.0                0.0
# Diclofenac_N4_2                   0.0                0.0                0.0
# Diclofenac_N5_1                   0.0                0.0                0.0
# Diclofenac_N5_2                   0.0                0.0                0.0
#
#                  Egan #violations  Muegge #violations  Bioavailability Score  \
# Primary ID
# Amlodipine_N1_1               0.0                 0.0                   0.55
# Amlodipine_N1_2               0.0                 0.0                   0.55
# Amlodipine_N2_1               0.0                 0.0                   0.55
# Amlodipine_N2_2               0.0                 0.0                   0.55
# Amlodipine_N4_1               0.0                 0.0                   0.55
# ...                           ...                 ...                    ...
# Diclofenac_N2_2               0.0                 0.0                   0.85
# Diclofenac_N4_1               0.0                 0.0                   0.85
# Diclofenac_N4_2               0.0                 0.0                   0.85
# Diclofenac_N5_1               0.0                 0.0                   0.85
# Diclofenac_N5_2               0.0                 0.0                   0.85
#
#                  PAINS #alerts  Brenk #alerts  Leadlikeness #violations  \
# Primary ID
# Amlodipine_N1_1            0.0            1.0                       2.0
# Amlodipine_N1_2            0.0            1.0                       2.0
# Amlodipine_N2_1            0.0            1.0                       2.0
# Amlodipine_N2_2            0.0            1.0                       2.0
# Amlodipine_N4_1            0.0            1.0                       2.0
# ...                        ...            ...                       ...
# Diclofenac_N2_2            0.0            0.0                       1.0
# Diclofenac_N4_1            0.0            0.0                       1.0
# Diclofenac_N4_2            0.0            0.0                       1.0
# Diclofenac_N5_1            0.0            0.0                       1.0
# Diclofenac_N5_2            0.0            0.0                       1.0
#
#                  Synthetic Accessibility
# Primary ID
# Amlodipine_N1_1                     4.39
# Amlodipine_N1_2                     4.39
# Amlodipine_N2_1                     4.39
# Amlodipine_N2_2                     4.39
# Amlodipine_N4_1                     4.39
# ...                                  ...
# Diclofenac_N2_2                     2.23
# Diclofenac_N4_1                     2.23
# Diclofenac_N4_2                     2.23
# Diclofenac_N5_1                     2.23
# Diclofenac_N5_2                     2.23
#
# [218 rows x 1515 columns]

# %%
y
# Out:
#                  Printlet weight
# Primary ID
# Amlodipine_N1_1            158.0
# Amlodipine_N1_2            186.0
# Amlodipine_N2_1            156.0
# Amlodipine_N2_2            147.0
# Amlodipine_N4_1            165.0
# ...                          ...
# Diclofenac_N2_2            173.0
# Diclofenac_N4_1            151.0
# Diclofenac_N4_2            162.0
# Diclofenac_N5_1            162.0
# Diclofenac_N5_2            156.0
#
# [218 rows x 1 columns]

# %%
non_numeric_columns = X.select_dtypes(exclude=['number']).columns
non_numeric_columns
# Out:
# Index([], dtype='object')

# %%
X.to_csv('X.csv')
y.to_csv('y.csv')
