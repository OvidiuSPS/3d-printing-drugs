# %%
import pandas as pd

# %%
# Specify the path to your Excel file
file_path = 'Etapa5 - completat 11.2024.xlsx'

# Read all sheets into a dictionary of DataFrames
all_sheets = pd.read_excel(file_path, sheet_name=None)


# Iterate through the dictionary of DataFrames
for sheet_name, df in all_sheets.items():
    # Add a new column with the sheet name
    df['SheetName'] = sheet_name
    
    # Assign the DataFrame to a variable named after the sheet name
    globals()[sheet_name] = df
    globals()[sheet_name].set_index('Primary ID', inplace=True)

    columns_to_drop = ['Sec ID', 'SheetName', 'Printlet weight']
    # Drop the columns only if they exist in the DataFrame
    globals()[sheet_name] = globals()[sheet_name].drop(columns=[col for col in columns_to_drop if col in globals()[sheet_name].columns], errors='ignore')

# %%
X = globals()['Input1_Etapa5']
y = globals()['Output_Etapa5']

# %%
X
# Out:
#                  API dose      %5min     %10min     %15min     %30min  \
# Primary ID
# Amlodipine_N1_1      7.90   6.824995  10.599703  14.395172  19.542900
# Amlodipine_N1_2      9.30  13.240678  16.853359  20.485702  20.485702
# Amlodipine_N2_1     23.40   3.087206   5.356809   7.638926  13.578082
# Amlodipine_N2_2     22.05  13.442931  17.108792  20.794604  15.275948
# Amlodipine_N3_1       NaN        NaN        NaN        NaN        NaN
# ...                   ...        ...        ...        ...        ...
# Diclofenac_N2_2     25.95   5.927844   9.993104  14.071073  26.080956
# Diclofenac_N4_1      7.55   7.781062  10.656150  15.479299  28.957761
# Diclofenac_N4_2      8.10   8.525924  16.088311  20.369692  30.854069
# Diclofenac_N5_1     24.30   7.800232  11.797752  16.138128  26.122993
# Diclofenac_N5_2     23.40   9.089186  14.589624  22.420710  38.055916
#
#                     %60min    %120min    %180min    %240min  API %  ...  \
# Primary ID                                                          ...
# Amlodipine_N1_1  31.676950  49.805138  52.670704  55.550666      5  ...
# Amlodipine_N1_2  34.369857  62.798687  62.798687  62.798687      5  ...
# Amlodipine_N2_1  25.862664  45.194778  50.321247  55.474810     15  ...
# Amlodipine_N2_2  26.572372  46.015217  46.015217  52.086360     15  ...
# Amlodipine_N3_1        NaN        NaN        NaN        NaN     25  ...
# ...                    ...        ...        ...        ...    ...  ...
# Diclofenac_N2_2  47.540045  78.132131  78.132131  81.922783     15  ...
# Diclofenac_N4_1  51.605898  89.404487  95.394807  95.394807      5  ...
# Diclofenac_N4_2  58.134071  89.632731  91.492950  91.492950      5  ...
# Diclofenac_N5_1  51.275688  80.987311  82.313628  82.433734     15  ...
# Diclofenac_N5_2  78.081678  84.145563  84.145563  84.145563     15  ...
#
#                  Lipinski #violations  Ghose #violations  Veber #violations  \
# Primary ID
# Amlodipine_N1_1                     0                  0                  0
# Amlodipine_N1_2                     0                  0                  0
# Amlodipine_N2_1                     0                  0                  0
# Amlodipine_N2_2                     0                  0                  0
# Amlodipine_N3_1                     0                  0                  0
# ...                               ...                ...                ...
# Diclofenac_N2_2                     0                  0                  0
# Diclofenac_N4_1                     0                  0                  0
# Diclofenac_N4_2                     0                  0                  0
# Diclofenac_N5_1                     0                  0                  0
# Diclofenac_N5_2                     0                  0                  0
#
#                  Egan #violations  Muegge #violations  Bioavailability Score  \
# Primary ID
# Amlodipine_N1_1                 0                   0                   0.55
# Amlodipine_N1_2                 0                   0                   0.55
# Amlodipine_N2_1                 0                   0                   0.55
# Amlodipine_N2_2                 0                   0                   0.55
# Amlodipine_N3_1                 0                   0                   0.55
# ...                           ...                 ...                    ...
# Diclofenac_N2_2                 0                   0                   0.85
# Diclofenac_N4_1                 0                   0                   0.85
# Diclofenac_N4_2                 0                   0                   0.85
# Diclofenac_N5_1                 0                   0                   0.85
# Diclofenac_N5_2                 0                   0                   0.85
#
#                  PAINS #alerts  Brenk #alerts  Leadlikeness #violations  \
# Primary ID
# Amlodipine_N1_1              0              1                         2
# Amlodipine_N1_2              0              1                         2
# Amlodipine_N2_1              0              1                         2
# Amlodipine_N2_2              0              1                         2
# Amlodipine_N3_1              0              1                         2
# ...                        ...            ...                       ...
# Diclofenac_N2_2              0              0                         1
# Diclofenac_N4_1              0              0                         1
# Diclofenac_N4_2              0              0                         1
# Diclofenac_N5_1              0              0                         1
# Diclofenac_N5_2              0              0                         1
#
#                  Synthetic Accessibility
# Primary ID
# Amlodipine_N1_1                     4.39
# Amlodipine_N1_2                     4.39
# Amlodipine_N2_1                     4.39
# Amlodipine_N2_2                     4.39
# Amlodipine_N3_1                     4.39
# ...                                  ...
# Diclofenac_N2_2                     2.23
# Diclofenac_N4_1                     2.23
# Diclofenac_N4_2                     2.23
# Diclofenac_N5_1                     2.23
# Diclofenac_N5_2                     2.23
#
# [292 rows x 1515 columns]

# %%
X.shape
# Out:
# (292, 1515)

# %%
y
# Out:
#                  Temp Z1  Temp Z2  Temp Z3  Temp Z4  Temp Z5  Screw speed
# Primary ID
# Amlodipine_N1_1      130      145      165      173      174           30
# Amlodipine_N1_2      130      145      165      173      174           30
# Amlodipine_N2_1      130      145      160      169      172           30
# Amlodipine_N2_2      130      145      160      169      172           30
# Amlodipine_N3_1      130      145      165      165      165           30
# ...                  ...      ...      ...      ...      ...          ...
# Diclofenac_N2_2      135      150      165      170      170           25
# Diclofenac_N4_1      135      150      160      165      165           30
# Diclofenac_N4_2      135      150      160      165      165           30
# Diclofenac_N5_1      135      150      155      160      160           25
# Diclofenac_N5_2      135      150      155      160      160           25
#
# [292 rows x 6 columns]

# %%
# List of columns to drop
columns_to_drop = ['Sec ID', 'SheetName']

# Drop the columns only if they exist in the DataFrame
X = X.drop(columns=[col for col in columns_to_drop if col in X.columns], errors='ignore')
y = y.drop(columns=[col for col in columns_to_drop if col in y.columns], errors='ignore')

# Check the first few rows after dropping the columns
print(X.head())
print(y.head())

# check nr de linii
assert X.shape[0] == y.shape[0]
# Out:
#                  API dose      %5min     %10min     %15min     %30min  \
# Primary ID
# Amlodipine_N1_1      7.90   6.824995  10.599703  14.395172  19.542900
# Amlodipine_N1_2      9.30  13.240678  16.853359  20.485702  20.485702
# Amlodipine_N2_1     23.40   3.087206   5.356809   7.638926  13.578082
# Amlodipine_N2_2     22.05  13.442931  17.108792  20.794604  15.275948
# Amlodipine_N3_1       NaN        NaN        NaN        NaN        NaN
#
#                     %60min    %120min    %180min    %240min  API %  ...  \
# Primary ID                                                          ...
# Amlodipine_N1_1  31.676950  49.805138  52.670704  55.550666      5  ...
# Amlodipine_N1_2  34.369857  62.798687  62.798687  62.798687      5  ...
# Amlodipine_N2_1  25.862664  45.194778  50.321247  55.474810     15  ...
# Amlodipine_N2_2  26.572372  46.015217  46.015217  52.086360     15  ...
# Amlodipine_N3_1        NaN        NaN        NaN        NaN     25  ...
#
#                  Lipinski #violations  Ghose #violations  Veber #violations  \
# Primary ID
# Amlodipine_N1_1                     0                  0                  0
# Amlodipine_N1_2                     0                  0                  0
# Amlodipine_N2_1                     0                  0                  0
# Amlodipine_N2_2                     0                  0                  0
# Amlodipine_N3_1                     0                  0                  0
#
#                  Egan #violations  Muegge #violations  Bioavailability Score  \
# Primary ID
# Amlodipine_N1_1                 0                   0                   0.55
# Amlodipine_N1_2                 0                   0                   0.55
# Amlodipine_N2_1                 0                   0                   0.55
# Amlodipine_N2_2                 0                   0                   0.55
# Amlodipine_N3_1                 0                   0                   0.55
#
#                  PAINS #alerts  Brenk #alerts  Leadlikeness #violations  \
# Primary ID
# Amlodipine_N1_1              0              1                         2
# Amlodipine_N1_2              0              1                         2
# Amlodipine_N2_1              0              1                         2
# Amlodipine_N2_2              0              1                         2
# Amlodipine_N3_1              0              1                         2
#
#                  Synthetic Accessibility
# Primary ID
# Amlodipine_N1_1                     4.39
# Amlodipine_N1_2                     4.39
# Amlodipine_N2_1                     4.39
# Amlodipine_N2_2                     4.39
# Amlodipine_N3_1                     4.39
#
# [5 rows x 1515 columns]
#                  Temp Z1  Temp Z2  Temp Z3  Temp Z4  Temp Z5  Screw speed
# Primary ID
# Amlodipine_N1_1      130      145      165      173      174           30
# Amlodipine_N1_2      130      145      165      173      174           30
# Amlodipine_N2_1      130      145      160      169      172           30
# Amlodipine_N2_2      130      145      160      169      172           30
# Amlodipine_N3_1      130      145      165      165      165           30

# %%
X.columns
# Out:
# Index(['API dose', '%5min', '%10min', '%15min', '%30min', '%60min', '%120min',
#        '%180min', '%240min', 'API %',
#        ...
#        'Lipinski #violations', 'Ghose #violations', 'Veber #violations',
#        'Egan #violations', 'Muegge #violations', 'Bioavailability Score',
#        'PAINS #alerts', 'Brenk #alerts', 'Leadlikeness #violations',
#        'Synthetic Accessibility'],
#       dtype='object', length=1515)

# %%
# Identify rows with NaNs
data = pd.merge(X, y, left_index=True, right_index=True)

rows_with_nans = data.isnull().any(axis=1)
num_rows_with_nans = rows_with_nans.sum()
total_rows = len(data)
fraction_rows_with_nans = num_rows_with_nans / total_rows

print(f"Number of rows with NaNs: {num_rows_with_nans}")
print(f"Fraction of rows with NaNs: {fraction_rows_with_nans:.2f}")

# Identify columns with NaNs
columns_with_nans = data.columns[data.isnull().any()].tolist()
num_columns_with_nans = len(columns_with_nans)

print(f"Columns with NaNs: {columns_with_nans}")

# Print detailed information about NaNs in each column
nan_info = data.isnull().sum()
print("\nDetailed NaN information:")
print(nan_info[nan_info > 0])
# Out:
# Number of rows with NaNs: 70
# Fraction of rows with NaNs: 0.24
# Columns with NaNs: ['API dose', '%5min', '%10min', '%15min', '%30min', '%60min', '%120min', '%180min', '%240min', 'MW_Spartan', 'Energy', 'Solvation E', 'HOMO', 'Dipol', 'Tautomeri', 'LUMO', 'Conformeri', 'Area A^2', 'Volum A^3', 'Acc area A^2', 'Min ElPot kJ/mol', 'MinLocIonPot kJ/mol', 'LogP', 'PSA A^2', 'Ovality', 'MaxElPot kJ/mo', 'Polaririzability', 'ZPE kJ/mol', 'H0', 'Cv', 'S0', 'G0']
#
# Detailed NaN information:
# API dose               56
# %5min                  56
# %10min                 56
# %15min                 56
# %30min                 56
# %60min                 56
# %120min                56
# %180min                56
# %240min                56
# MW_Spartan             22
# Energy                 22
# Solvation E            22
# HOMO                   22
# Dipol                  22
# Tautomeri              22
# LUMO                   22
# Conformeri             22
# Area A^2               22
# Volum A^3              22
# Acc area A^2           22
# Min ElPot kJ/mol       22
# MinLocIonPot kJ/mol    22
# LogP                   22
# PSA A^2                22
# Ovality                22
# MaxElPot kJ/mo         22
# Polaririzability       22
# ZPE kJ/mol             22
# H0                     22
# Cv                     22
# S0                     22
# G0                     22
# dtype: int64

# %%
# Get the indices of rows containing NaN values in df_X
nan_indices = data[data.isna().any(axis=1)].index
print(f"Rows with NaNs: {nan_indices}")

# Remove rows with these indices in both df_X and df_Y
X.drop(nan_indices, inplace=True)
y.drop(nan_indices, inplace=True)
# Out:
# Rows with NaNs: Index(['Amlodipine_N3_1', 'Amlodipine_N3_2', 'Amlodipine_N6_1',
#        'Amlodipine_N6_2', 'Amlodipine_N7_1', 'Amlodipine_N7_2',
#        'Amlodipine_N8_1', 'Amlodipine_N8_2', 'Amlodipine_N9_1',
#        'Amlodipine_N9_2', 'Carvedilol_N3_1', 'Carvedilol_N3_2',
#        'Carvedilol_N9_1', 'Carvedilol_N9_2', 'Spironolactona_N2_1',
#        'Spironolactona_N2_2', 'Spironolactona_N3_1', 'Spironolactona_N3_2',
#        'Spironolactona_N4_1', 'Spironolactona_N4_2', 'Spironolactona_N5_1',
#        'Spironolactona_N5_2', 'Spironolactona_N6_1', 'Spironolactona_N6_2',
#        'Spironolactona_N7_1', 'Spironolactona_N7_2', 'Spironolactona_N9_1',
#        'Spironolactona_N9_2', 'Spironolactona_N10_1', 'Spironolactona_N10_2',
#        'Spironolactona_N11_1', 'Spironolactona_N11_2', 'Cafeina_N1_1',
#        'Cafeina_N1_2', 'Cafeina_N3_1', 'Cafeina_N3_2', 'Cafeina_N4_1',
#        'Cafeina_N4_2', 'Cafeina_N6_1', 'Cafeina_N6_2', 'Cafeina_N7_1',
#        'Cafeina_N7_2', 'Cafeina_N8_1', 'Cafeina_N8_2', 'Cafeina_N10_1',
#        'Cafeina_N10_2', 'Cafeina_N11_1', 'Cafeina_N11_2', 'Azithromycine_N1_1',
#        'Azithromycine_N1_2', 'Azithromycine_N2_1', 'Azithromycine_N2_2',
#        'Azithromycine_N3_1', 'Azithromycine_N3_2', 'Azithromycine_N4_1',
#        'Azithromycine_N4_2', 'Azithromycine_N5_1', 'Azithromycine_N5_2',
#        'Azithromycine_N6_1', 'Azithromycine_N6_2', 'Azithromycine_N7_1',
#        'Azithromycine_N7_2', 'Azithromycine_N8_1', 'Azithromycine_N8_2',
#        'Azithromycine_N9_1', 'Azithromycine_N9_2', 'Azithromycine_N10_1',
#        'Azithromycine_N10_2', 'Azithromycine_N11_1', 'Azithromycine_N11_2'],
#       dtype='object', name='Primary ID')

# %%
X
# Out:
#                  API dose      %5min     %10min     %15min     %30min  \
# Primary ID
# Amlodipine_N1_1      7.90   6.824995  10.599703  14.395172  19.542900
# Amlodipine_N1_2      9.30  13.240678  16.853359  20.485702  20.485702
# Amlodipine_N2_1     23.40   3.087206   5.356809   7.638926  13.578082
# Amlodipine_N2_2     22.05  13.442931  17.108792  20.794604  15.275948
# Amlodipine_N4_1      8.25   4.643496   9.536276  14.456096  17.031157
# ...                   ...        ...        ...        ...        ...
# Diclofenac_N2_2     25.95   5.927844   9.993104  14.071073  26.080956
# Diclofenac_N4_1      7.55   7.781062  10.656150  15.479299  28.957761
# Diclofenac_N4_2      8.10   8.525924  16.088311  20.369692  30.854069
# Diclofenac_N5_1     24.30   7.800232  11.797752  16.138128  26.122993
# Diclofenac_N5_2     23.40   9.089186  14.589624  22.420710  38.055916
#
#                     %60min    %120min    %180min    %240min  API %  ...  \
# Primary ID                                                          ...
# Amlodipine_N1_1  31.676950  49.805138  52.670704  55.550666      5  ...
# Amlodipine_N1_2  34.369857  62.798687  62.798687  62.798687      5  ...
# Amlodipine_N2_1  25.862664  45.194778  50.321247  55.474810     15  ...
# Amlodipine_N2_2  26.572372  46.015217  46.015217  52.086360     15  ...
# Amlodipine_N4_1  29.929859  45.669082  52.007638  58.380012      5  ...
# ...                    ...        ...        ...        ...    ...  ...
# Diclofenac_N2_2  47.540045  78.132131  78.132131  81.922783     15  ...
# Diclofenac_N4_1  51.605898  89.404487  95.394807  95.394807      5  ...
# Diclofenac_N4_2  58.134071  89.632731  91.492950  91.492950      5  ...
# Diclofenac_N5_1  51.275688  80.987311  82.313628  82.433734     15  ...
# Diclofenac_N5_2  78.081678  84.145563  84.145563  84.145563     15  ...
#
#                  Lipinski #violations  Ghose #violations  Veber #violations  \
# Primary ID
# Amlodipine_N1_1                     0                  0                  0
# Amlodipine_N1_2                     0                  0                  0
# Amlodipine_N2_1                     0                  0                  0
# Amlodipine_N2_2                     0                  0                  0
# Amlodipine_N4_1                     0                  0                  0
# ...                               ...                ...                ...
# Diclofenac_N2_2                     0                  0                  0
# Diclofenac_N4_1                     0                  0                  0
# Diclofenac_N4_2                     0                  0                  0
# Diclofenac_N5_1                     0                  0                  0
# Diclofenac_N5_2                     0                  0                  0
#
#                  Egan #violations  Muegge #violations  Bioavailability Score  \
# Primary ID
# Amlodipine_N1_1                 0                   0                   0.55
# Amlodipine_N1_2                 0                   0                   0.55
# Amlodipine_N2_1                 0                   0                   0.55
# Amlodipine_N2_2                 0                   0                   0.55
# Amlodipine_N4_1                 0                   0                   0.55
# ...                           ...                 ...                    ...
# Diclofenac_N2_2                 0                   0                   0.85
# Diclofenac_N4_1                 0                   0                   0.85
# Diclofenac_N4_2                 0                   0                   0.85
# Diclofenac_N5_1                 0                   0                   0.85
# Diclofenac_N5_2                 0                   0                   0.85
#
#                  PAINS #alerts  Brenk #alerts  Leadlikeness #violations  \
# Primary ID
# Amlodipine_N1_1              0              1                         2
# Amlodipine_N1_2              0              1                         2
# Amlodipine_N2_1              0              1                         2
# Amlodipine_N2_2              0              1                         2
# Amlodipine_N4_1              0              1                         2
# ...                        ...            ...                       ...
# Diclofenac_N2_2              0              0                         1
# Diclofenac_N4_1              0              0                         1
# Diclofenac_N4_2              0              0                         1
# Diclofenac_N5_1              0              0                         1
# Diclofenac_N5_2              0              0                         1
#
#                  Synthetic Accessibility
# Primary ID
# Amlodipine_N1_1                     4.39
# Amlodipine_N1_2                     4.39
# Amlodipine_N2_1                     4.39
# Amlodipine_N2_2                     4.39
# Amlodipine_N4_1                     4.39
# ...                                  ...
# Diclofenac_N2_2                     2.23
# Diclofenac_N4_1                     2.23
# Diclofenac_N4_2                     2.23
# Diclofenac_N5_1                     2.23
# Diclofenac_N5_2                     2.23
#
# [222 rows x 1515 columns]

# %%
y
# Out:
#                  Temp Z1  Temp Z2  Temp Z3  Temp Z4  Temp Z5  Screw speed
# Primary ID
# Amlodipine_N1_1      130      145      165      173      174           30
# Amlodipine_N1_2      130      145      165      173      174           30
# Amlodipine_N2_1      130      145      160      169      172           30
# Amlodipine_N2_2      130      145      160      169      172           30
# Amlodipine_N4_1      130      145      160      164      163           30
# ...                  ...      ...      ...      ...      ...          ...
# Diclofenac_N2_2      135      150      165      170      170           25
# Diclofenac_N4_1      135      150      160      165      165           30
# Diclofenac_N4_2      135      150      160      165      165           30
# Diclofenac_N5_1      135      150      155      160      160           25
# Diclofenac_N5_2      135      150      155      160      160           25
#
# [222 rows x 6 columns]

# %%
non_numeric_columns = X.select_dtypes(exclude=['number']).columns
non_numeric_columns
# Out:
# Index([], dtype='object')

# %%
X.to_csv('X.csv')
y.to_csv('y.csv')
